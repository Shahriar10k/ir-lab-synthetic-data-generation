# %%
# ============================================================
# evaluate_cnnbilstm_v7_a6000_random_subject_split.py
#
# CNN-BiLSTM downstream HAR evaluation for your v7 synthetic data.
#
# Main target:
#   NVIDIA RTX A6000 48GB
#
# Channel switch:
#   CHANNEL_MODE = "6ch" -> ACC_x, ACC_y, ACC_z, BVP, EDA, TEMP
#   CHANNEL_MODE = "4ch" -> ACC_x, ACC_y, ACC_z, BVP
#
# Subject split:
#   Random subject-wise split with fixed SEED.
#   With 15 subjects:
#       Train = 10 subjects
#       Val   = 2 subjects
#       Test  = 3 subjects
#
# Input real:
#   processed_all_subjects_64hz/all_X.npy
#   processed_all_subjects_64hz/all_y.npy
#   processed_all_subjects_64hz/all_subject.npy
#
# Input synthetic:
#   all6_average_synthetic_subject_outputs/generated_subjects_all_X.npy
#   all6_average_synthetic_subject_outputs/generated_subjects_all_y.npy
#   all6_average_synthetic_subject_outputs/generated_subjects_all_subject.npy
#
# Experiments:
#   1. Real train -> Real test
#   2. Real train -> Synthetic test
#   3. Synthetic train -> Real test
#   4. Real + Synthetic train -> Real test
#
# Outputs:
#   cnnbilstm_v7_results_a6000_6ch/
#   or
#   cnnbilstm_v7_results_a6000_4ch/
# ============================================================

import copy
import random
from pathlib import Path
from contextlib import nullcontext

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    precision_recall_fscore_support,
)


# ============================================================
# Main switch
# ============================================================

# Choose one:
CHANNEL_MODE = "6ch"
# CHANNEL_MODE = "4ch"


# ============================================================
# Paths
# ============================================================

PROJECT_ROOT = Path("/home/iailab42/khans1/projects/ir")

REAL_DIR = PROJECT_ROOT / "data"
SYN_DIR = PROJECT_ROOT / "data" / "synthetic"

REAL_X_PATH = REAL_DIR / "all_X.npy"
REAL_Y_PATH = REAL_DIR / "all_y.npy"
REAL_SUBJECT_PATH = REAL_DIR / "all_subject.npy"

SYN_X_PATH = SYN_DIR /"prior"/ "all_X_synthetic.npy"
SYN_Y_PATH = SYN_DIR /"prior"/ "all_y_synthetic.npy"
SYN_SUBJECT_PATH = SYN_DIR /"prior"/ "all_subject_synthetic.npy"

# SYN_X_PATH = SYN_DIR / "timevae"/ "all_X_synthetic.npy"
# SYN_Y_PATH = SYN_DIR / "timevae"/ "all_y_synthetic.npy"
# SYN_SUBJECT_PATH = SYN_DIR / "timevae"/ "all_subject_synthetic.npy"
# SYN_METADATA_PATH = SYN_DIR / "timevae"/ "all_metadata_synthetic.csv"

OUT_DIR = PROJECT_ROOT / "results" / f"cnnbilstm_kovae_downstream_{CHANNEL_MODE}_prior"
# OUT_DIR = PROJECT_ROOT / "results" / f"cnnbilstm_timevae_downstream_{CHANNEL_MODE}"
OUT_DIR.mkdir(parents=True, exist_ok=True)


# ============================================================
# General config
# ============================================================

SEED = 42
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

ALL_CHANNEL_NAMES = ["ACC_x", "ACC_y", "ACC_z", "BVP", "EDA", "TEMP"]

if CHANNEL_MODE == "6ch":
    CHANNEL_NAMES = ["ACC_x", "ACC_y", "ACC_z", "BVP", "EDA", "TEMP"]
elif CHANNEL_MODE == "4ch":
    CHANNEL_NAMES = ["ACC_x", "ACC_y", "ACC_z", "BVP"]
else:
    raise ValueError("CHANNEL_MODE must be '6ch' or '4ch'.")

USE_CHANNEL_INDICES = [ALL_CHANNEL_NAMES.index(ch) for ch in CHANNEL_NAMES]
NUM_CHANNELS = len(CHANNEL_NAMES)

ACTIVITY_IDS = [1, 2, 3, 4, 5, 6, 7, 8]
NUM_CLASSES = len(ACTIVITY_IDS)

WINDOW_LEN = 512

# Paper-style subsequence setup adapted to your 512-sample windows:
# paper: 128 = 4 x 32
# yours: 512 = 4 x 128
N_SEQ = 4
N_STEPS = WINDOW_LEN // N_SEQ

if WINDOW_LEN % N_SEQ != 0:
    raise ValueError("WINDOW_LEN must be divisible by N_SEQ.")

# Random subject-wise split counts.
N_TEST_SUBJECTS = 3
N_VAL_SUBJECTS = 2

# Leave empty for random split.
# Or manually set, e.g. TEST_SUBJECTS = ["S13", "S14", "S15"]
TEST_SUBJECTS = []
VAL_SUBJECTS = []


# ============================================================
# A6000 training settings
# ============================================================

BATCH_SIZE = 384
NUM_WORKERS = 6

EPOCHS_REAL_TO_REAL = 100
EPOCHS_REAL_TO_SYN = 100
EPOCHS_SYN_TO_REAL = 100
EPOCHS_REAL_PLUS_SYN_TO_REAL = 100

LR = 1e-3
WEIGHT_DECAY = 1e-4
DROPOUT = 0.5

USE_CLASS_WEIGHTS = True
USE_AMP = True
USE_TF32 = True

SAVE_CONFUSION_MATRIX_PNG = True

# Early stopping based on validation Macro-F1.
PATIENCE = 15


# ============================================================
# CUDA backend settings
# ============================================================

if DEVICE == "cuda":
    torch.backends.cuda.matmul.allow_tf32 = USE_TF32
    torch.backends.cudnn.allow_tf32 = USE_TF32

    # More reproducible. You can set True for speed, but False is safer.
    torch.backends.cudnn.benchmark = False


# ============================================================
# Reproducibility
# ============================================================

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


def autocast_context():
    """
    New non-deprecated AMP autocast syntax.

    Old deprecated:
        torch.cuda.amp.autocast()

    New:
        torch.amp.autocast("cuda", enabled=True/False)
    """
    if DEVICE == "cuda":
        return torch.amp.autocast("cuda", enabled=USE_AMP)

    return nullcontext()


# ============================================================
# Label helpers
# ============================================================

LABEL_TO_INDEX = {label: i for i, label in enumerate(ACTIVITY_IDS)}
INDEX_TO_LABEL = {i: label for label, i in LABEL_TO_INDEX.items()}


def labels_to_indices(y):
    y = np.asarray(y).astype(np.int64)
    out = np.zeros_like(y, dtype=np.int64)

    for i, lab in enumerate(y):
        lab = int(lab)

        if lab not in LABEL_TO_INDEX:
            raise ValueError(f"Unexpected label {lab}. Expected labels: {ACTIVITY_IDS}")

        out[i] = LABEL_TO_INDEX[lab]

    return out


def indices_to_labels(y_idx):
    y_idx = np.asarray(y_idx).astype(np.int64)
    return np.array([INDEX_TO_LABEL[int(i)] for i in y_idx], dtype=np.int64)


# ============================================================
# File helpers
# ============================================================

def require_file(path):
    path = Path(path)

    if not path.exists():
        error_message = (
            f"\nMissing file: {path}\n"
            f"Make sure these files exist:\n"
            f"  /home/iailab42/khans1/projects/data/all_X.npy\n"
            f"  /home/iailab42/khans1/projects/data/all_y.npy\n"
            f"  /home/iailab42/khans1/projects/data/all_subject.npy\n"
            f"  /home/iailab42/khans1/projects/data/synthetic/all_X_synthetic.npy\n"
            f"  /home/iailab42/khans1/projects/data/synthetic/all_y_synthetic.npy\n"
            f"  /home/iailab42/khans1/projects/data/synthetic/all_subject_synthetic.npy\n"
        )
        raise FileNotFoundError(error_message)

    return path


# ============================================================
# Load data
# ============================================================

def load_data(x_path, y_path, subject_path, name):
    require_file(x_path)
    require_file(y_path)
    require_file(subject_path)

    X = np.load(x_path).astype(np.float32)
    y = np.load(y_path).astype(np.int64)
    subjects = np.load(subject_path, allow_pickle=True).astype(str)

    if X.ndim != 3:
        raise ValueError(f"{name} X should be [N, T, C], got {X.shape}")

    if X.shape[1] != WINDOW_LEN:
        raise ValueError(
            f"{name} expected window length {WINDOW_LEN}, got {X.shape[1]}"
        )

    if X.shape[2] != len(ALL_CHANNEL_NAMES):
        raise ValueError(
            f"{name} expected original 6 channels, got {X.shape[2]}"
        )

    if len(X) != len(y):
        raise ValueError(f"{name} X/y mismatch: {len(X)} vs {len(y)}")

    if len(y) != len(subjects):
        raise ValueError(f"{name} y/subjects mismatch: {len(y)} vs {len(subjects)}")

    keep = np.isin(y, np.array(ACTIVITY_IDS, dtype=np.int64))

    X = X[keep]
    y = y[keep]
    subjects = subjects[keep]

    # Channel switch happens here.
    X = X[:, :, USE_CHANNEL_INDICES].astype(np.float32)

    print("\n" + "=" * 70)
    print(f"Loaded {name}")
    print("=" * 70)
    print("X:", X.shape)
    print("y:", y.shape)
    print("subjects:", subjects.shape)
    print("CHANNEL_MODE:", CHANNEL_MODE)
    print("Using channels:", CHANNEL_NAMES)
    print("Label counts:", dict(zip(*np.unique(y, return_counts=True))))
    print("Subject counts:", dict(zip(*np.unique(subjects, return_counts=True))))

    return X, y, subjects


def load_real_data():
    return load_data(
        REAL_X_PATH,
        REAL_Y_PATH,
        REAL_SUBJECT_PATH,
        name="real data",
    )


def load_synthetic_data():
    return load_data(
        SYN_X_PATH,
        SYN_Y_PATH,
        SYN_SUBJECT_PATH,
        name="synthetic data",
    )


# ============================================================
# Subject split
# ============================================================

def subject_sort_key(s):
    s = str(s)

    if s.startswith("S"):
        try:
            return int(s[1:])
        except Exception:
            return s

    return s


def make_subject_split(real_subjects):
    unique_subjects = sorted(np.unique(real_subjects).astype(str), key=subject_sort_key)

    if len(unique_subjects) < (N_TEST_SUBJECTS + N_VAL_SUBJECTS + 1):
        raise ValueError(
            f"Not enough real subjects for split. Found: {unique_subjects}"
        )

    # Manual split if user fills TEST_SUBJECTS / VAL_SUBJECTS.
    if len(TEST_SUBJECTS) > 0 or len(VAL_SUBJECTS) > 0:
        if len(TEST_SUBJECTS) == 0 or len(VAL_SUBJECTS) == 0:
            raise ValueError(
                "If using manual split, set both TEST_SUBJECTS and VAL_SUBJECTS."
            )

        test_subjects = list(TEST_SUBJECTS)
        val_subjects = list(VAL_SUBJECTS)

        train_subjects = [
            s for s in unique_subjects
            if s not in test_subjects and s not in val_subjects
        ]

        split_mode = "manual"

    else:
        # Fixed random subject split.
        rng = np.random.default_rng(SEED)
        shuffled_subjects = np.array(unique_subjects, dtype=object)
        rng.shuffle(shuffled_subjects)
        shuffled_subjects = shuffled_subjects.tolist()

        test_subjects = shuffled_subjects[:N_TEST_SUBJECTS]
        val_subjects = shuffled_subjects[
            N_TEST_SUBJECTS:N_TEST_SUBJECTS + N_VAL_SUBJECTS
        ]
        train_subjects = shuffled_subjects[N_TEST_SUBJECTS + N_VAL_SUBJECTS:]

        split_mode = f"random_fixed_seed_{SEED}"

    train_subjects = sorted(train_subjects, key=subject_sort_key)
    val_subjects = sorted(val_subjects, key=subject_sort_key)
    test_subjects = sorted(test_subjects, key=subject_sort_key)

    if len(set(train_subjects) & set(val_subjects)) > 0:
        raise ValueError("Train/val subject overlap detected.")

    if len(set(train_subjects) & set(test_subjects)) > 0:
        raise ValueError("Train/test subject overlap detected.")

    if len(set(val_subjects) & set(test_subjects)) > 0:
        raise ValueError("Val/test subject overlap detected.")

    print("\n" + "=" * 70)
    print("Real subject split")
    print("=" * 70)
    print("Split mode:     ", split_mode)
    print("Train subjects: ", train_subjects)
    print("Val subjects:   ", val_subjects)
    print("Test subjects:  ", test_subjects)
    print("Train % by subject:", len(train_subjects) / len(unique_subjects) * 100.0)
    print("Val % by subject:  ", len(val_subjects) / len(unique_subjects) * 100.0)
    print("Test % by subject: ", len(test_subjects) / len(unique_subjects) * 100.0)

    split_df = pd.DataFrame({
        "split": ["train", "val", "test"],
        "subjects": [
            ",".join(train_subjects),
            ",".join(val_subjects),
            ",".join(test_subjects),
        ],
        "num_subjects": [
            len(train_subjects),
            len(val_subjects),
            len(test_subjects),
        ],
        "percentage_by_subject": [
            len(train_subjects) / len(unique_subjects) * 100.0,
            len(val_subjects) / len(unique_subjects) * 100.0,
            len(test_subjects) / len(unique_subjects) * 100.0,
        ],
        "split_mode": [split_mode, split_mode, split_mode],
        "seed": [SEED, SEED, SEED],
    })

    split_df.to_csv(OUT_DIR / "real_subject_split.csv", index=False)

    return train_subjects, val_subjects, test_subjects


def filter_by_subjects(X, y, subjects, selected_subjects):
    selected_subjects = set([str(s) for s in selected_subjects])
    mask = np.array([str(s) in selected_subjects for s in subjects], dtype=bool)

    return X[mask], y[mask], subjects[mask]


# ============================================================
# Dataset / DataLoader
# ============================================================

class HARWindowDataset(Dataset):
    def __init__(self, X, y_original):
        X = np.asarray(X, dtype=np.float32)
        y_original = np.asarray(y_original, dtype=np.int64)
        y_idx = labels_to_indices(y_original)

        if X.ndim != 3:
            raise ValueError(f"Expected X [N,T,C], got {X.shape}")

        if X.shape[1] != WINDOW_LEN:
            raise ValueError(f"Expected window length {WINDOW_LEN}, got {X.shape[1]}")

        if X.shape[2] != NUM_CHANNELS:
            raise ValueError(f"Expected {NUM_CHANNELS} channels, got {X.shape[2]}")

        self.X = torch.from_numpy(X)
        self.y = torch.from_numpy(y_idx).long()
        self.y_original = y_original

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


def make_loader(X, y, batch_size, shuffle):
    dataset = HARWindowDataset(X, y)

    # Avoid BatchNorm crash from final train batch of size 1.
    drop_last = bool(shuffle and len(dataset) > batch_size)

    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available(),
        drop_last=drop_last,
        persistent_workers=(NUM_WORKERS > 0),
    )

    return loader


def compute_class_weights(y_original):
    y_idx = labels_to_indices(y_original)
    counts = np.bincount(y_idx, minlength=NUM_CLASSES).astype(np.float32)

    counts = np.maximum(counts, 1.0)

    weights = counts.sum() / (NUM_CLASSES * counts)
    weights = weights / weights.mean()

    return torch.tensor(weights, dtype=torch.float32)


# ============================================================
# CNN-BiLSTM model
# ============================================================

class TimeDistributedConvBranch(nn.Module):
    def __init__(self, in_channels, kernel_size, dropout):
        super().__init__()

        padding = kernel_size // 2

        self.net = nn.Sequential(
            nn.Conv1d(
                in_channels=in_channels,
                out_channels=64,
                kernel_size=kernel_size,
                padding=padding,
            ),
            nn.ReLU(inplace=True),

            nn.Conv1d(
                in_channels=64,
                out_channels=32,
                kernel_size=kernel_size,
                padding=padding,
            ),
            nn.ReLU(inplace=True),

            nn.Dropout(dropout),
            nn.MaxPool1d(kernel_size=2),
        )

    def forward(self, x):
        # x: [B, S, steps, C]
        B, S, steps, C = x.shape

        # TimeDistributed Conv1D:
        # [B, S, steps, C] -> [B*S, C, steps]
        x = x.reshape(B * S, steps, C)
        x = x.transpose(1, 2)

        h = self.net(x)

        # h: [B*S, 32, steps/2]
        h = h.reshape(B, S, -1)

        return h


class MultiBranchCNNBiLSTM(nn.Module):
    def __init__(
        self,
        num_channels,
        num_classes,
        n_seq,
        n_steps,
        dropout,
    ):
        super().__init__()

        self.num_channels = num_channels
        self.num_classes = num_classes
        self.n_seq = n_seq
        self.n_steps = n_steps

        self.branch_k3 = TimeDistributedConvBranch(
            in_channels=num_channels,
            kernel_size=3,
            dropout=dropout,
        )

        self.branch_k7 = TimeDistributedConvBranch(
            in_channels=num_channels,
            kernel_size=7,
            dropout=dropout,
        )

        self.branch_k11 = TimeDistributedConvBranch(
            in_channels=num_channels,
            kernel_size=11,
            dropout=dropout,
        )

        branch_out_dim = 32 * (n_steps // 2)
        lstm_input_dim = branch_out_dim * 3

        self.bilstm1 = nn.LSTM(
            input_size=lstm_input_dim,
            hidden_size=64,
            batch_first=True,
            bidirectional=True,
        )

        self.bilstm2 = nn.LSTM(
            input_size=64 * 2,
            hidden_size=32,
            batch_first=True,
            bidirectional=True,
        )

        self.fc = nn.Linear(32 * 2, 128)
        self.bn = nn.BatchNorm1d(128)
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Linear(128, num_classes)

    def forward(self, x):
        # x: [B, 512, C]
        B, T, C = x.shape

        expected_t = self.n_seq * self.n_steps

        if T != expected_t:
            raise ValueError(f"Expected T={expected_t}, got T={T}")

        if C != self.num_channels:
            raise ValueError(f"Expected C={self.num_channels}, got C={C}")

        # [B, 512, C] -> [B, 4, 128, C]
        x = x.reshape(B, self.n_seq, self.n_steps, C)

        h3 = self.branch_k3(x)
        h7 = self.branch_k7(x)
        h11 = self.branch_k11(x)

        h = torch.cat([h3, h7, h11], dim=-1)

        h, _ = self.bilstm1(h)
        h, (h_n, _) = self.bilstm2(h)

        # h_n shape: [num_layers * num_directions, B, hidden]
        # last forward = h_n[-2], last backward = h_n[-1]
        h_final = torch.cat([h_n[-2], h_n[-1]], dim=1)

        z = self.fc(h_final)
        z = self.bn(z)
        z = F.relu(z)
        z = self.dropout(z)

        logits = self.classifier(z)

        return logits


def make_new_model():
    model = MultiBranchCNNBiLSTM(
        num_channels=NUM_CHANNELS,
        num_classes=NUM_CLASSES,
        n_seq=N_SEQ,
        n_steps=N_STEPS,
        dropout=DROPOUT,
    )

    return model


# ============================================================
# Metrics
# ============================================================

def evaluate_model(model, loader):
    model.eval()

    all_true = []
    all_pred = []
    all_prob = []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(DEVICE, non_blocking=True)
            y_batch = y_batch.to(DEVICE, non_blocking=True)

            with autocast_context():
                logits = model(X_batch)

            probs = torch.softmax(logits.float(), dim=1)
            pred = torch.argmax(probs, dim=1)

            all_true.append(y_batch.cpu().numpy())
            all_pred.append(pred.cpu().numpy())
            all_prob.append(probs.cpu().numpy())

    y_true_idx = np.concatenate(all_true)
    y_pred_idx = np.concatenate(all_pred)
    y_prob = np.concatenate(all_prob)

    y_true = indices_to_labels(y_true_idx)
    y_pred = indices_to_labels(y_pred_idx)

    return y_true, y_pred, y_prob


def compute_metrics(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=np.int64)
    y_pred = np.asarray(y_pred, dtype=np.int64)

    accuracy = accuracy_score(y_true, y_pred)

    macro_precision = precision_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="macro",
        zero_division=0,
    )

    macro_recall = recall_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="macro",
        zero_division=0,
    )

    macro_f1 = f1_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="macro",
        zero_division=0,
    )

    weighted_precision = precision_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="weighted",
        zero_division=0,
    )

    weighted_recall = recall_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="weighted",
        zero_division=0,
    )

    weighted_f1 = f1_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="weighted",
        zero_division=0,
    )

    # Balanced accuracy for multiclass = average recall across classes.
    # This is intentionally same definition as macro recall.
    balanced_accuracy = macro_recall

    metrics = {
        "accuracy": accuracy,
        "macro_precision": macro_precision,
        "macro_recall": macro_recall,
        "macro_f1": macro_f1,
        "weighted_precision": weighted_precision,
        "weighted_recall": weighted_recall,
        "weighted_f1": weighted_f1,
        "balanced_accuracy": balanced_accuracy,
    }

    return metrics


def compute_per_class_metrics(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=np.int64)
    y_pred = np.asarray(y_pred, dtype=np.int64)

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        zero_division=0,
    )

    cm = confusion_matrix(y_true, y_pred, labels=ACTIVITY_IDS)

    row_sum = cm.sum(axis=1)
    diag = np.diag(cm)

    per_class_accuracy = np.divide(
        diag,
        row_sum,
        out=np.zeros_like(diag, dtype=np.float64),
        where=row_sum != 0,
    )

    rows = []

    for i, act in enumerate(ACTIVITY_IDS):
        rows.append({
            "activity": act,
            "precision": float(precision[i]),
            "recall": float(recall[i]),
            "f1": float(f1[i]),
            "per_class_accuracy_same_as_recall": float(per_class_accuracy[i]),
            "support": int(support[i]),
        })

    per_class_df = pd.DataFrame(rows)

    return per_class_df, cm


# ============================================================
# Plot / save results
# ============================================================

def save_confusion_matrix_png(cm, experiment_name):
    fig, ax = plt.subplots(figsize=(8, 7))

    im = ax.imshow(cm, interpolation="nearest")
    fig.colorbar(im, ax=ax)

    ax.set_title(f"Confusion Matrix | {experiment_name}")
    ax.set_xlabel("Predicted activity")
    ax.set_ylabel("True activity")

    tick_marks = np.arange(len(ACTIVITY_IDS))
    ax.set_xticks(tick_marks)
    ax.set_yticks(tick_marks)
    ax.set_xticklabels([str(a) for a in ACTIVITY_IDS])
    ax.set_yticklabels([str(a) for a in ACTIVITY_IDS])

    threshold = cm.max() / 2.0 if cm.max() > 0 else 0.5

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            value = int(cm[i, j])
            ax.text(
                j,
                i,
                str(value),
                ha="center",
                va="center",
                color="white" if value > threshold else "black",
                fontsize=9,
            )

    plt.tight_layout()

    save_path = OUT_DIR / f"{experiment_name}_confusion_matrix.png"
    plt.savefig(save_path, dpi=150)
    plt.close()

    print("Saved:", save_path)


def save_final_results(model, test_loader, experiment_name):
    y_true, y_pred, y_prob = evaluate_model(model, test_loader)

    metrics = compute_metrics(y_true, y_pred)
    per_class_df, cm = compute_per_class_metrics(y_true, y_pred)

    cm_df = pd.DataFrame(
        cm,
        index=[f"true_{a}" for a in ACTIVITY_IDS],
        columns=[f"pred_{a}" for a in ACTIVITY_IDS],
    )

    pred_df = pd.DataFrame({
        "y_true": y_true,
        "y_pred": y_pred,
        "correct": y_true == y_pred,
    })

    for i, act in enumerate(ACTIVITY_IDS):
        pred_df[f"prob_activity_{act}"] = y_prob[:, i]

    per_class_path = OUT_DIR / f"{experiment_name}_per_class_metrics.csv"
    cm_path = OUT_DIR / f"{experiment_name}_confusion_matrix.csv"
    pred_path = OUT_DIR / f"{experiment_name}_predictions.csv"

    per_class_df.to_csv(per_class_path, index=False)
    cm_df.to_csv(cm_path)
    pred_df.to_csv(pred_path, index=False)

    if SAVE_CONFUSION_MATRIX_PNG:
        save_confusion_matrix_png(cm, experiment_name)

    print("\n" + "=" * 70)
    print(f"Final test results | {experiment_name}")
    print("=" * 70)

    for k, v in metrics.items():
        print(f"{k:24s}: {v:.6f}")

    print("\nPer-class metrics:")
    print(per_class_df)

    print("\nConfusion matrix:")
    print(cm_df)

    print("\nSaved:")
    print(" ", per_class_path)
    print(" ", cm_path)
    print(" ", pred_path)

    summary_row = {
        "experiment": experiment_name,
        "hardware": "A6000",
        "channel_mode": CHANNEL_MODE,
        "channels": ",".join(CHANNEL_NAMES),
        **metrics,
    }

    return summary_row


# ============================================================
# Training
# ============================================================

def train_model(
    model,
    train_loader,
    val_loader,
    y_train_original,
    epochs,
    lr,
    experiment_name,
):
    model = model.to(DEVICE)

    if USE_CLASS_WEIGHTS:
        class_weights = compute_class_weights(y_train_original).to(DEVICE)

        print("\nClass weights:")
        for act, w in zip(ACTIVITY_IDS, class_weights.detach().cpu().numpy()):
            print(f"  Activity {act}: {w:.4f}")

        criterion = nn.CrossEntropyLoss(weight=class_weights)
    else:
        criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=lr,
        weight_decay=WEIGHT_DECAY,
    )

    # New non-deprecated GradScaler syntax.
    scaler = torch.amp.GradScaler(
        "cuda",
        enabled=(USE_AMP and DEVICE == "cuda"),
    )

    best_val_macro_f1 = -1.0
    best_state = None
    epochs_without_improvement = 0

    history_rows = []

    for epoch in range(1, epochs + 1):
        model.train()

        total_loss = 0.0
        total_correct = 0
        total_seen = 0

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(DEVICE, non_blocking=True)
            y_batch = y_batch.to(DEVICE, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with autocast_context():
                logits = model(X_batch)
                loss = criterion(logits, y_batch)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            with torch.no_grad():
                pred = torch.argmax(logits, dim=1)
                correct = (pred == y_batch).sum().item()

            bs = len(y_batch)
            total_loss += loss.item() * bs
            total_correct += correct
            total_seen += bs

        train_loss = total_loss / max(total_seen, 1)
        train_accuracy = total_correct / max(total_seen, 1)

        val_true, val_pred, _ = evaluate_model(model, val_loader)
        val_metrics = compute_metrics(val_true, val_pred)

        row = {
            "epoch": epoch,
            "train_loss": train_loss,
            "train_accuracy": train_accuracy,
            "val_accuracy": val_metrics["accuracy"],
            "val_macro_precision": val_metrics["macro_precision"],
            "val_macro_recall": val_metrics["macro_recall"],
            "val_macro_f1": val_metrics["macro_f1"],
            "val_balanced_accuracy": val_metrics["balanced_accuracy"],
        }

        history_rows.append(row)

        print(
            f"{experiment_name} | "
            f"Epoch {epoch:03d}/{epochs} | "
            f"loss={train_loss:.4f} | "
            f"train_acc={train_accuracy:.4f} | "
            f"val_acc={val_metrics['accuracy']:.4f} | "
            f"val_macro_f1={val_metrics['macro_f1']:.4f} | "
            f"val_bal_acc={val_metrics['balanced_accuracy']:.4f}",
            flush=True,
        )

        if val_metrics["macro_f1"] > best_val_macro_f1:
            best_val_macro_f1 = val_metrics["macro_f1"]
            best_state = copy.deepcopy(model.state_dict())
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1

        if epochs_without_improvement >= PATIENCE:
            print(
                f"Early stopping at epoch {epoch}. "
                f"Best val macro-F1 = {best_val_macro_f1:.4f}"
            )
            break

    if best_state is not None:
        model.load_state_dict(best_state)

    history_df = pd.DataFrame(history_rows)
    history_path = OUT_DIR / f"{experiment_name}_training_history.csv"
    history_df.to_csv(history_path, index=False)

    model_path = OUT_DIR / f"{experiment_name}_best_model.pt"

    torch.save(
        {
            "model_state_dict": model.state_dict(),
            "hardware": "A6000",
            "channel_mode": CHANNEL_MODE,
            "channels": CHANNEL_NAMES,
            "activity_ids": ACTIVITY_IDS,
            "window_len": WINDOW_LEN,
            "n_seq": N_SEQ,
            "n_steps": N_STEPS,
            "best_val_macro_f1": best_val_macro_f1,
            "batch_size": BATCH_SIZE,
            "use_amp": USE_AMP,
            "use_tf32": USE_TF32,
            "seed": SEED,
        },
        model_path,
    )

    print("Saved history:", history_path)
    print("Saved model:", model_path)

    return model, history_df


# ============================================================
# Experiment runner
# ============================================================

def train_once_and_evaluate(
    experiment_train_name,
    X_train,
    y_train,
    X_val,
    y_val,
    test_sets,
    epochs,
):
    print("\n" + "#" * 80)
    print(f"Training: {experiment_train_name}")
    print("#" * 80)
    print("Train X:", X_train.shape)
    print("Val X:  ", X_val.shape)
    print("Train label counts:", dict(zip(*np.unique(y_train, return_counts=True))))
    print("Val label counts:  ", dict(zip(*np.unique(y_val, return_counts=True))))

    train_loader = make_loader(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        shuffle=True,
    )

    val_loader = make_loader(
        X_val,
        y_val,
        batch_size=BATCH_SIZE,
        shuffle=False,
    )

    model = make_new_model()

    model, history_df = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        y_train_original=y_train,
        epochs=epochs,
        lr=LR,
        experiment_name=experiment_train_name,
    )

    summary_rows = []

    for test_name, X_test, y_test in test_sets:
        print("\n" + "-" * 70)
        print(f"Testing trained model on: {test_name}")
        print("-" * 70)
        print("Test X:", X_test.shape)
        print("Test label counts:", dict(zip(*np.unique(y_test, return_counts=True))))

        test_loader = make_loader(
            X_test,
            y_test,
            batch_size=BATCH_SIZE,
            shuffle=False,
        )

        summary_row = save_final_results(
            model=model,
            test_loader=test_loader,
            experiment_name=test_name,
        )

        summary_rows.append(summary_row)

    return summary_rows


# ============================================================
# Main
# ============================================================

def main():
    print("=" * 80)
    print("CNN-BiLSTM v7 downstream evaluation | A6000 version")
    print("=" * 80)
    print("Device:", DEVICE)

    if DEVICE == "cuda":
        print("GPU:", torch.cuda.get_device_name(0))

    print("CHANNEL_MODE:", CHANNEL_MODE)
    print("Using channels:", CHANNEL_NAMES)
    print("NUM_CHANNELS:", NUM_CHANNELS)
    print("BATCH_SIZE:", BATCH_SIZE)
    print("NUM_WORKERS:", NUM_WORKERS)
    print("USE_AMP:", USE_AMP)
    print("USE_TF32:", USE_TF32)
    print("SEED:", SEED)
    print("Output directory:", OUT_DIR)

    # ------------------------------------------------------------
    # Load data
    # ------------------------------------------------------------

    real_X, real_y, real_subjects = load_real_data()
    syn_X, syn_y, syn_subjects = load_synthetic_data()

    # ------------------------------------------------------------
    # Split real subjects
    # ------------------------------------------------------------

    train_subjects, val_subjects, test_subjects = make_subject_split(real_subjects)

    X_real_train, y_real_train, sub_real_train = filter_by_subjects(
        real_X,
        real_y,
        real_subjects,
        train_subjects,
    )

    X_real_val, y_real_val, sub_real_val = filter_by_subjects(
        real_X,
        real_y,
        real_subjects,
        val_subjects,
    )

    X_real_test, y_real_test, sub_real_test = filter_by_subjects(
        real_X,
        real_y,
        real_subjects,
        test_subjects,
    )

    print("\n" + "=" * 70)
    print("Final real split sizes")
    print("=" * 70)
    print("Real train:", X_real_train.shape)
    print("Real val:  ", X_real_val.shape)
    print("Real test: ", X_real_test.shape)
    print("Synthetic: ", syn_X.shape)

    split_size_df = pd.DataFrame([
        {
            "split": "real_train",
            "num_windows": len(X_real_train),
            "subjects": ",".join(train_subjects),
        },
        {
            "split": "real_val",
            "num_windows": len(X_real_val),
            "subjects": ",".join(val_subjects),
        },
        {
            "split": "real_test",
            "num_windows": len(X_real_test),
            "subjects": ",".join(test_subjects),
        },
        {
            "split": "synthetic_all",
            "num_windows": len(syn_X),
            "subjects": ",".join(sorted(np.unique(syn_subjects).astype(str))),
        },
    ])

    split_size_df.to_csv(OUT_DIR / "data_split_summary.csv", index=False)

    summary_rows = []

    # ------------------------------------------------------------
    # 1 and 2:
    # Train on real train subjects.
    # Test on real test subjects and synthetic data.
    # ------------------------------------------------------------

    summary_rows.extend(
        train_once_and_evaluate(
            experiment_train_name="train_real",
            X_train=X_real_train,
            y_train=y_real_train,
            X_val=X_real_val,
            y_val=y_real_val,
            test_sets=[
                ("real_train_to_real_test", X_real_test, y_real_test),
                ("real_train_to_synthetic_test", syn_X, syn_y),
            ],
            epochs=EPOCHS_REAL_TO_REAL,
        )
    )

    # ------------------------------------------------------------
    # 3:
    # Train on synthetic.
    # Test on real test subjects.
    #
    # Real validation is used for early stopping only.
    # ------------------------------------------------------------

    summary_rows.extend(
        train_once_and_evaluate(
            experiment_train_name="train_synthetic",
            X_train=syn_X,
            y_train=syn_y,
            X_val=X_real_val,
            y_val=y_real_val,
            test_sets=[
                ("synthetic_train_to_real_test", X_real_test, y_real_test),
            ],
            epochs=EPOCHS_SYN_TO_REAL,
        )
    )

    # ------------------------------------------------------------
    # 4:
    # Train on real train subjects + synthetic.
    # Test on real test subjects.
    # ------------------------------------------------------------

    X_real_plus_syn = np.concatenate([X_real_train, syn_X], axis=0).astype(np.float32)
    y_real_plus_syn = np.concatenate([y_real_train, syn_y], axis=0).astype(np.int64)

    summary_rows.extend(
        train_once_and_evaluate(
            experiment_train_name="train_real_plus_synthetic",
            X_train=X_real_plus_syn,
            y_train=y_real_plus_syn,
            X_val=X_real_val,
            y_val=y_real_val,
            test_sets=[
                ("real_plus_synthetic_train_to_real_test", X_real_test, y_real_test),
            ],
            epochs=EPOCHS_REAL_PLUS_SYN_TO_REAL,
        )
    )

    # ------------------------------------------------------------
    # Save summary
    # ------------------------------------------------------------

    summary_df = pd.DataFrame(summary_rows)

    metric_cols = [
        "accuracy",
        "macro_precision",
        "macro_recall",
        "macro_f1",
        "weighted_precision",
        "weighted_recall",
        "weighted_f1",
        "balanced_accuracy",
    ]

    first_cols = [
        "experiment",
        "hardware",
        "channel_mode",
        "channels",
    ]

    summary_df = summary_df[first_cols + metric_cols]

    summary_path = OUT_DIR / "summary_metrics.csv"
    summary_df.to_csv(summary_path, index=False)

    print("\n" + "=" * 80)
    print("ALL CNN-BiLSTM EXPERIMENTS DONE")
    print("=" * 80)
    print(summary_df)
    print("\nSaved summary:", summary_path)
    print("All outputs saved in:", OUT_DIR)


if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# CNN-BiLSTM v7 downstream evaluation | A6000 version
# ================================================================================
# Device: cuda
# GPU: NVIDIA RTX A6000
# CHANNEL_MODE: 6ch
# Using channels: ['ACC_x', 'ACC_y', 'ACC_z', 'BVP', 'EDA', 'TEMP']
# NUM_CHANNELS: 6
# BATCH_SIZE: 384
# NUM_WORKERS: 6
# USE_AMP: True
# USE_TF32: True
# SEED: 42
# Output directory: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior
#
# ======================================================================
# Loaded real data
# ======================================================================
# X: (46907, 512, 6)
# y: (46907,)
# subjects: (46907,)
# CHANNEL_MODE: 6ch
# Using channels: ['ACC_x', 'ACC_y', 'ACC_z', 'BVP', 'EDA', 'TEMP']
# Label counts: {np.int64(1): np.int64(4534), np.int64(2): np.int64(3205), np.int64(3): np.int64(2277), np.int64(4): np.int64(3439), np.int64(5): np.int64(6807), np.int64(6): np.int64(13518), np.int64(7): np.int64(4660), np.int64(8): np.int64(8467)}
# Subject counts: {np.str_('S1'): np.int64(3445), np.str_('S10'): np.int64(3532), np.str_('S11'): np.int64(3487), np.str_('S12'): np.int64(2938), np.str_('S13'): np.int64(3356), np.str_('S14'): np.int64(3177), np.str_('S15'): np.int64(2919), np.str_('S2'): np.int64(2818), np.str_('S3'): np.int64(3344), np.str_('S4'): np.int64(3295), np.str_('S5'): np.int64(3345), np.str_('S6'): np.int64(1463), np.str_('S7'): np.int64(3553), np.str_('S8'): np.int64(2978), np.str_('S9'): np.int64(3257)}
#
# ======================================================================
# Loaded synthetic data
# ======================================================================
# X: (8000, 512, 6)
# y: (8000,)
# subjects: (8000,)
# CHANNEL_MODE: 6ch
# Using channels: ['ACC_x', 'ACC_y', 'ACC_z', 'BVP', 'EDA', 'TEMP']
# Label counts: {np.int64(1): np.int64(1000), np.int64(2): np.int64(1000), np.int64(3): np.int64(1000), np.int64(4): np.int64(1000), np.int64(5): np.int64(1000), np.int64(6): np.int64(1000), np.int64(7): np.int64(1000), np.int64(8): np.int64(1000)}
# Subject counts: {np.str_('SYN_001'): np.int64(800), np.str_('SYN_002'): np.int64(800), np.str_('SYN_003'): np.int64(800), np.str_('SYN_004'): np.int64(800), np.str_('SYN_005'): np.int64(800), np.str_('SYN_006'): np.int64(800), np.str_('SYN_007'): np.int64(800), np.str_('SYN_008'): np.int64(800), np.str_('SYN_009'): np.int64(800), np.str_('SYN_010'): np.int64(800)}
#
# ======================================================================
# Real subject split
# ======================================================================
# Split mode:      random_fixed_seed_42
# Train subjects:  [np.str_('S2'), np.str_('S3'), np.str_('S5'), np.str_('S6'), np.str_('S9'), np.str_('S11'), np.str_('S12'), np.str_('S13'), np.str_('S14'), np.str_('S15')]
# Val subjects:    [np.str_('S1'), np.str_('S4')]
# Test subjects:   [np.str_('S7'), np.str_('S8'), np.str_('S10')]
# Train % by subject: 66.66666666666666
# Val % by subject:   13.333333333333334
# Test % by subject:  20.0
#
# ======================================================================
# Final real split sizes
# ======================================================================
# Real train: (30104, 512, 6)
# Real val:   (6740, 512, 6)
# Real test:  (10063, 512, 6)
# Synthetic:  (8000, 512, 6)
#
# ################################################################################
# Training: train_real
# ################################################################################
# Train X: (30104, 512, 6)
# Val X:   (6740, 512, 6)
# Train label counts: {np.int64(1): np.int64(3004), np.int64(2): np.int64(2170), np.int64(3): np.int64(1502), np.int64(4): np.int64(2304), np.int64(5): np.int64(4501), np.int64(6): np.int64(8251), np.int64(7): np.int64(2862), np.int64(8): np.int64(5510)}
# Val label counts:   {np.int64(1): np.int64(629), np.int64(2): np.int64(400), np.int64(3): np.int64(331), np.int64(4): np.int64(438), np.int64(5): np.int64(943), np.int64(6): np.int64(2120), np.int64(7): np.int64(670), np.int64(8): np.int64(1209)}
#
# Class weights:
#   Activity 1: 0.9622
#   Activity 2: 1.3320
#   Activity 3: 1.9244
#   Activity 4: 1.2545
#   Activity 5: 0.6422
#   Activity 6: 0.3503
#   Activity 7: 1.0099
#   Activity 8: 0.5246
# train_real | Epoch 001/100 | loss=0.8033 | train_acc=0.6774 | val_acc=0.5993 | val_macro_f1=0.6660 | val_bal_acc=0.7257
# train_real | Epoch 002/100 | loss=0.3447 | train_acc=0.8398 | val_acc=0.5877 | val_macro_f1=0.6805 | val_bal_acc=0.7287
# train_real | Epoch 003/100 | loss=0.2190 | train_acc=0.8972 | val_acc=0.5717 | val_macro_f1=0.6418 | val_bal_acc=0.7027
# train_real | Epoch 004/100 | loss=0.1686 | train_acc=0.9190 | val_acc=0.5567 | val_macro_f1=0.6270 | val_bal_acc=0.6917
# train_real | Epoch 005/100 | loss=0.1221 | train_acc=0.9415 | val_acc=0.5638 | val_macro_f1=0.6509 | val_bal_acc=0.6961
# train_real | Epoch 006/100 | loss=0.0760 | train_acc=0.9644 | val_acc=0.6079 | val_macro_f1=0.7037 | val_bal_acc=0.7345
# train_real | Epoch 007/100 | loss=0.0782 | train_acc=0.9629 | val_acc=0.5896 | val_macro_f1=0.6711 | val_bal_acc=0.7082
# train_real | Epoch 008/100 | loss=0.0664 | train_acc=0.9684 | val_acc=0.5622 | val_macro_f1=0.6354 | val_bal_acc=0.6928
# train_real | Epoch 009/100 | loss=0.0546 | train_acc=0.9747 | val_acc=0.5807 | val_macro_f1=0.6569 | val_bal_acc=0.6869
# train_real | Epoch 010/100 | loss=0.0441 | train_acc=0.9795 | val_acc=0.6174 | val_macro_f1=0.6998 | val_bal_acc=0.7393
# train_real | Epoch 011/100 | loss=0.0398 | train_acc=0.9818 | val_acc=0.5280 | val_macro_f1=0.6055 | val_bal_acc=0.6582
# train_real | Epoch 012/100 | loss=0.0503 | train_acc=0.9765 | val_acc=0.5840 | val_macro_f1=0.6406 | val_bal_acc=0.6888
# train_real | Epoch 013/100 | loss=0.0402 | train_acc=0.9813 | val_acc=0.6353 | val_macro_f1=0.7198 | val_bal_acc=0.7541
# train_real | Epoch 014/100 | loss=0.0354 | train_acc=0.9852 | val_acc=0.6157 | val_macro_f1=0.6822 | val_bal_acc=0.7224
# train_real | Epoch 015/100 | loss=0.0312 | train_acc=0.9864 | val_acc=0.6217 | val_macro_f1=0.6749 | val_bal_acc=0.7048
# train_real | Epoch 016/100 | loss=0.0263 | train_acc=0.9888 | val_acc=0.6366 | val_macro_f1=0.7236 | val_bal_acc=0.7548
# train_real | Epoch 017/100 | loss=0.0196 | train_acc=0.9908 | val_acc=0.6539 | val_macro_f1=0.7355 | val_bal_acc=0.7567
# train_real | Epoch 018/100 | loss=0.0244 | train_acc=0.9893 | val_acc=0.5950 | val_macro_f1=0.6866 | val_bal_acc=0.7219
# train_real | Epoch 019/100 | loss=0.0239 | train_acc=0.9893 | val_acc=0.6049 | val_macro_f1=0.6694 | val_bal_acc=0.7151
# train_real | Epoch 020/100 | loss=0.0235 | train_acc=0.9903 | val_acc=0.6325 | val_macro_f1=0.6940 | val_bal_acc=0.7340
# train_real | Epoch 021/100 | loss=0.0443 | train_acc=0.9817 | val_acc=0.6252 | val_macro_f1=0.7108 | val_bal_acc=0.7538
# train_real | Epoch 022/100 | loss=0.0409 | train_acc=0.9818 | val_acc=0.6556 | val_macro_f1=0.7179 | val_bal_acc=0.7409
# train_real | Epoch 023/100 | loss=0.0438 | train_acc=0.9827 | val_acc=0.5938 | val_macro_f1=0.6652 | val_bal_acc=0.7160
# train_real | Epoch 024/100 | loss=0.0231 | train_acc=0.9900 | val_acc=0.6375 | val_macro_f1=0.7189 | val_bal_acc=0.7481
# train_real | Epoch 025/100 | loss=0.0219 | train_acc=0.9921 | val_acc=0.6153 | val_macro_f1=0.6742 | val_bal_acc=0.7090
# train_real | Epoch 026/100 | loss=0.0182 | train_acc=0.9912 | val_acc=0.6304 | val_macro_f1=0.7262 | val_bal_acc=0.7606
# train_real | Epoch 027/100 | loss=0.0114 | train_acc=0.9954 | val_acc=0.6279 | val_macro_f1=0.7189 | val_bal_acc=0.7529
# train_real | Epoch 028/100 | loss=0.0148 | train_acc=0.9943 | val_acc=0.5697 | val_macro_f1=0.6344 | val_bal_acc=0.6901
# train_real | Epoch 029/100 | loss=0.0235 | train_acc=0.9891 | val_acc=0.5944 | val_macro_f1=0.6659 | val_bal_acc=0.7137
# train_real | Epoch 030/100 | loss=0.0188 | train_acc=0.9919 | val_acc=0.6055 | val_macro_f1=0.6699 | val_bal_acc=0.7162
# train_real | Epoch 031/100 | loss=0.0190 | train_acc=0.9921 | val_acc=0.6036 | val_macro_f1=0.6674 | val_bal_acc=0.7095
# train_real | Epoch 032/100 | loss=0.0192 | train_acc=0.9910 | val_acc=0.6154 | val_macro_f1=0.6972 | val_bal_acc=0.7344
# Early stopping at epoch 32. Best val macro-F1 = 0.7355
# Saved history: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/train_real_training_history.csv
# Saved model: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/train_real_best_model.pt
#
# ----------------------------------------------------------------------
# Testing trained model on: real_train_to_real_test
# ----------------------------------------------------------------------
# Test X: (10063, 512, 6)
# Test label counts: {np.int64(1): np.int64(901), np.int64(2): np.int64(635), np.int64(3): np.int64(444), np.int64(4): np.int64(697), np.int64(5): np.int64(1363), np.int64(6): np.int64(3147), np.int64(7): np.int64(1128), np.int64(8): np.int64(1748)}
# Saved: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_train_to_real_test_confusion_matrix.png
#
# ======================================================================
# Final test results | real_train_to_real_test
# ======================================================================
# accuracy                : 0.527576
# macro_precision         : 0.520254
# macro_recall            : 0.563808
# macro_f1                : 0.532448
# weighted_precision      : 0.535367
# weighted_recall         : 0.527576
# weighted_f1             : 0.524904
# balanced_accuracy       : 0.563808
#
# Per-class metrics:
#    activity  precision    recall        f1  per_class_accuracy_same_as_recall  \
# 0         1   0.659247  0.854606  0.744321                           0.854606
# 1         2   0.571613  0.697638  0.628369                           0.697638
# 2         3   0.317503  0.527027  0.396274                           0.527027
# 3         4   0.345416  0.464849  0.396330                           0.464849
# 4         5   0.602335  0.643434  0.622206                           0.643434
# 5         6   0.537190  0.475056  0.504216                           0.475056
# 6         7   0.702934  0.509752  0.590956                           0.509752
# 7         8   0.425793  0.338101  0.376913                           0.338101
#
#    support
# 0      901
# 1      635
# 2      444
# 3      697
# 4     1363
# 5     3147
# 6     1128
# 7     1748
#
# Confusion matrix:
#         pred_1  pred_2  pred_3  pred_4  pred_5  pred_6  pred_7  pred_8
# true_1     770      93       1       0       0      37       0       0
# true_2      58     443       0       0       0      14       0     120
# true_3       0      40     234       3      28      16      73      50
# true_4       5      25       2     324     166     134      41       0
# true_5       0       1     137       6     877     170       8     164
# true_6     182     123     323     156     362    1495      98     408
# true_7       9      31       0       0       3     455     575      55
# true_8     144      19      40     449      20     462      23     591
#
# Saved:
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_train_to_real_test_per_class_metrics.csv
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_train_to_real_test_confusion_matrix.csv
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_train_to_real_test_predictions.csv
#
# ----------------------------------------------------------------------
# Testing trained model on: real_train_to_synthetic_test
# ----------------------------------------------------------------------
# Test X: (8000, 512, 6)
# Test label counts: {np.int64(1): np.int64(1000), np.int64(2): np.int64(1000), np.int64(3): np.int64(1000), np.int64(4): np.int64(1000), np.int64(5): np.int64(1000), np.int64(6): np.int64(1000), np.int64(7): np.int64(1000), np.int64(8): np.int64(1000)}
# Saved: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_train_to_synthetic_test_confusion_matrix.png
#
# ======================================================================
# Final test results | real_train_to_synthetic_test
# ======================================================================
# accuracy                : 0.541250
# macro_precision         : 0.490293
# macro_recall            : 0.541250
# macro_f1                : 0.483267
# weighted_precision      : 0.490293
# weighted_recall         : 0.541250
# weighted_f1             : 0.483267
# balanced_accuracy       : 0.541250
#
# Per-class metrics:
#    activity  precision  recall        f1  per_class_accuracy_same_as_recall  \
# 0         1   0.778271   0.702  0.738170                              0.702
# 1         2   0.431104   0.535  0.477465                              0.535
# 2         3   0.486224   0.900  0.631357                              0.900
# 3         4   0.935450   0.884  0.908997                              0.884
# 4         5   0.502513   0.900  0.644930                              0.900
# 5         6   0.288785   0.309  0.298551                              0.309
# 6         7   0.000000   0.000  0.000000                              0.000
# 7         8   0.500000   0.100  0.166667                              0.100
#
#    support
# 0     1000
# 1     1000
# 2     1000
# 3     1000
# 4     1000
# 5     1000
# 6     1000
# 7     1000
#
# Confusion matrix:
#         pred_1  pred_2  pred_3  pred_4  pred_5  pred_6  pred_7  pred_8
# true_1     702     198     100       0       0       0       0       0
# true_2       0     535     465       0       0       0       0       0
# true_3       0       0     900       0     100       0       0       0
# true_4       0      13     103     884       0       0       0       0
# true_5       0       0       0      61     900      39       0       0
# true_6       0       0       0       0     591     309       0     100
# true_7     100       0     282       0       0     618       0       0
# true_8     100     495       1       0     200     104       0     100
#
# Saved:
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_train_to_synthetic_test_per_class_metrics.csv
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_train_to_synthetic_test_confusion_matrix.csv
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_train_to_synthetic_test_predictions.csv
#
# ################################################################################
# Training: train_synthetic
# ################################################################################
# Train X: (8000, 512, 6)
# Val X:   (6740, 512, 6)
# Train label counts: {np.int64(1): np.int64(1000), np.int64(2): np.int64(1000), np.int64(3): np.int64(1000), np.int64(4): np.int64(1000), np.int64(5): np.int64(1000), np.int64(6): np.int64(1000), np.int64(7): np.int64(1000), np.int64(8): np.int64(1000)}
# Val label counts:   {np.int64(1): np.int64(629), np.int64(2): np.int64(400), np.int64(3): np.int64(331), np.int64(4): np.int64(438), np.int64(5): np.int64(943), np.int64(6): np.int64(2120), np.int64(7): np.int64(670), np.int64(8): np.int64(1209)}
#
# Class weights:
#   Activity 1: 1.0000
#   Activity 2: 1.0000
#   Activity 3: 1.0000
#   Activity 4: 1.0000
#   Activity 5: 1.0000
#   Activity 6: 1.0000
#   Activity 7: 1.0000
#   Activity 8: 1.0000
# train_synthetic | Epoch 001/100 | loss=0.6181 | train_acc=0.9047 | val_acc=0.4654 | val_macro_f1=0.4975 | val_bal_acc=0.5610
# train_synthetic | Epoch 002/100 | loss=0.1198 | train_acc=0.9997 | val_acc=0.5016 | val_macro_f1=0.5400 | val_bal_acc=0.5978
# train_synthetic | Epoch 003/100 | loss=0.0545 | train_acc=1.0000 | val_acc=0.5098 | val_macro_f1=0.5499 | val_bal_acc=0.6063
# train_synthetic | Epoch 004/100 | loss=0.0331 | train_acc=1.0000 | val_acc=0.5073 | val_macro_f1=0.5513 | val_bal_acc=0.6041
# train_synthetic | Epoch 005/100 | loss=0.0239 | train_acc=1.0000 | val_acc=0.5047 | val_macro_f1=0.5470 | val_bal_acc=0.6033
# train_synthetic | Epoch 006/100 | loss=0.0187 | train_acc=1.0000 | val_acc=0.5000 | val_macro_f1=0.5405 | val_bal_acc=0.5961
# train_synthetic | Epoch 007/100 | loss=0.0151 | train_acc=1.0000 | val_acc=0.5043 | val_macro_f1=0.5445 | val_bal_acc=0.6025
# train_synthetic | Epoch 008/100 | loss=0.0129 | train_acc=1.0000 | val_acc=0.5067 | val_macro_f1=0.5470 | val_bal_acc=0.6051
# train_synthetic | Epoch 009/100 | loss=0.0106 | train_acc=1.0000 | val_acc=0.5025 | val_macro_f1=0.5405 | val_bal_acc=0.5992
# train_synthetic | Epoch 010/100 | loss=0.0092 | train_acc=1.0000 | val_acc=0.5073 | val_macro_f1=0.5495 | val_bal_acc=0.6030
# train_synthetic | Epoch 011/100 | loss=0.0079 | train_acc=1.0000 | val_acc=0.4981 | val_macro_f1=0.5335 | val_bal_acc=0.5929
# train_synthetic | Epoch 012/100 | loss=0.0067 | train_acc=1.0000 | val_acc=0.5009 | val_macro_f1=0.5400 | val_bal_acc=0.5961
# train_synthetic | Epoch 013/100 | loss=0.0067 | train_acc=1.0000 | val_acc=0.5003 | val_macro_f1=0.5394 | val_bal_acc=0.5969
# train_synthetic | Epoch 014/100 | loss=0.0061 | train_acc=1.0000 | val_acc=0.4985 | val_macro_f1=0.5345 | val_bal_acc=0.5934
# train_synthetic | Epoch 015/100 | loss=0.0049 | train_acc=1.0000 | val_acc=0.5037 | val_macro_f1=0.5445 | val_bal_acc=0.5996
# train_synthetic | Epoch 016/100 | loss=0.0051 | train_acc=1.0000 | val_acc=0.5089 | val_macro_f1=0.5498 | val_bal_acc=0.6093
# train_synthetic | Epoch 017/100 | loss=0.0044 | train_acc=1.0000 | val_acc=0.4936 | val_macro_f1=0.5308 | val_bal_acc=0.5900
# train_synthetic | Epoch 018/100 | loss=0.0041 | train_acc=1.0000 | val_acc=0.5043 | val_macro_f1=0.5424 | val_bal_acc=0.6016
# train_synthetic | Epoch 019/100 | loss=0.0039 | train_acc=1.0000 | val_acc=0.4981 | val_macro_f1=0.5350 | val_bal_acc=0.5927
# Early stopping at epoch 19. Best val macro-F1 = 0.5513
# Saved history: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/train_synthetic_training_history.csv
# Saved model: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/train_synthetic_best_model.pt
#
# ----------------------------------------------------------------------
# Testing trained model on: synthetic_train_to_real_test
# ----------------------------------------------------------------------
# Test X: (10063, 512, 6)
# Test label counts: {np.int64(1): np.int64(901), np.int64(2): np.int64(635), np.int64(3): np.int64(444), np.int64(4): np.int64(697), np.int64(5): np.int64(1363), np.int64(6): np.int64(3147), np.int64(7): np.int64(1128), np.int64(8): np.int64(1748)}
# Saved: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/synthetic_train_to_real_test_confusion_matrix.png
#
# ======================================================================
# Final test results | synthetic_train_to_real_test
# ======================================================================
# accuracy                : 0.454437
# macro_precision         : 0.505343
# macro_recall            : 0.526580
# macro_f1                : 0.470665
# weighted_precision      : 0.561744
# weighted_recall         : 0.454437
# weighted_f1             : 0.433980
# balanced_accuracy       : 0.526580
#
# Per-class metrics:
#    activity  precision    recall        f1  per_class_accuracy_same_as_recall  \
# 0         1   0.340455  0.813541  0.480026                           0.813541
# 1         2   0.860996  0.653543  0.743062                           0.653543
# 2         3   0.182380  0.265766  0.216315                           0.265766
# 3         4   0.405158  0.698709  0.512902                           0.698709
# 4         5   0.629577  0.655906  0.642472                           0.655906
# 5         6   0.752174  0.164919  0.270524                           0.164919
# 6         7   0.505629  0.437943  0.469359                           0.437943
# 7         8   0.366372  0.522311  0.430660                           0.522311
#
#    support
# 0      901
# 1      635
# 2      444
# 3      697
# 4     1363
# 5     3147
# 6     1128
# 7     1748
#
# Confusion matrix:
#         pred_1  pred_2  pred_3  pred_4  pred_5  pred_6  pred_7  pred_8
# true_1     733      35       0       2       0       0      96      35
# true_2       8     415       0       0       0       5      16     191
# true_3      79       3     118      27     128       3      74      12
# true_4       2       0       0     487      41      60       0     107
# true_5       0       0     117      17     894      32       0     303
# true_6     750       4     385     211     356     519     207     715
# true_7     337       7      27       0       0      47     494     216
# true_8     244      18       0     458       1      24      90     913
#
# Saved:
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/synthetic_train_to_real_test_per_class_metrics.csv
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/synthetic_train_to_real_test_confusion_matrix.csv
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/synthetic_train_to_real_test_predictions.csv
#
# ################################################################################
# Training: train_real_plus_synthetic
# ################################################################################
# Train X: (38104, 512, 6)
# Val X:   (6740, 512, 6)
# Train label counts: {np.int64(1): np.int64(4004), np.int64(2): np.int64(3170), np.int64(3): np.int64(2502), np.int64(4): np.int64(3304), np.int64(5): np.int64(5501), np.int64(6): np.int64(9251), np.int64(7): np.int64(3862), np.int64(8): np.int64(6510)}
# Val label counts:   {np.int64(1): np.int64(629), np.int64(2): np.int64(400), np.int64(3): np.int64(331), np.int64(4): np.int64(438), np.int64(5): np.int64(943), np.int64(6): np.int64(2120), np.int64(7): np.int64(670), np.int64(8): np.int64(1209)}
#
# Class weights:
#   Activity 1: 1.0142
#   Activity 2: 1.2811
#   Activity 3: 1.6231
#   Activity 4: 1.2291
#   Activity 5: 0.7382
#   Activity 6: 0.4390
#   Activity 7: 1.0515
#   Activity 8: 0.6238
# train_real_plus_synthetic | Epoch 001/100 | loss=0.6444 | train_acc=0.7575 | val_acc=0.5690 | val_macro_f1=0.6318 | val_bal_acc=0.6911
# train_real_plus_synthetic | Epoch 002/100 | loss=0.2540 | train_acc=0.8902 | val_acc=0.6196 | val_macro_f1=0.6821 | val_bal_acc=0.7212
# train_real_plus_synthetic | Epoch 003/100 | loss=0.1682 | train_acc=0.9255 | val_acc=0.5788 | val_macro_f1=0.6643 | val_bal_acc=0.7137
# train_real_plus_synthetic | Epoch 004/100 | loss=0.1244 | train_acc=0.9471 | val_acc=0.6107 | val_macro_f1=0.6664 | val_bal_acc=0.7204
# train_real_plus_synthetic | Epoch 005/100 | loss=0.0823 | train_acc=0.9636 | val_acc=0.6553 | val_macro_f1=0.7345 | val_bal_acc=0.7633
# train_real_plus_synthetic | Epoch 006/100 | loss=0.0782 | train_acc=0.9652 | val_acc=0.5567 | val_macro_f1=0.6334 | val_bal_acc=0.6875
# train_real_plus_synthetic | Epoch 007/100 | loss=0.0570 | train_acc=0.9755 | val_acc=0.6151 | val_macro_f1=0.6861 | val_bal_acc=0.7318
# train_real_plus_synthetic | Epoch 008/100 | loss=0.0418 | train_acc=0.9811 | val_acc=0.5826 | val_macro_f1=0.6720 | val_bal_acc=0.7096
# train_real_plus_synthetic | Epoch 009/100 | loss=0.0377 | train_acc=0.9832 | val_acc=0.6444 | val_macro_f1=0.7201 | val_bal_acc=0.7524
# train_real_plus_synthetic | Epoch 010/100 | loss=0.0430 | train_acc=0.9820 | val_acc=0.5999 | val_macro_f1=0.6684 | val_bal_acc=0.7157
# train_real_plus_synthetic | Epoch 011/100 | loss=0.0453 | train_acc=0.9808 | val_acc=0.5773 | val_macro_f1=0.6850 | val_bal_acc=0.7138
# train_real_plus_synthetic | Epoch 012/100 | loss=0.0403 | train_acc=0.9824 | val_acc=0.6285 | val_macro_f1=0.7245 | val_bal_acc=0.7591
# train_real_plus_synthetic | Epoch 013/100 | loss=0.0323 | train_acc=0.9864 | val_acc=0.6499 | val_macro_f1=0.7333 | val_bal_acc=0.7578
# train_real_plus_synthetic | Epoch 014/100 | loss=0.0295 | train_acc=0.9881 | val_acc=0.6058 | val_macro_f1=0.6960 | val_bal_acc=0.7245
# train_real_plus_synthetic | Epoch 015/100 | loss=0.0290 | train_acc=0.9876 | val_acc=0.6349 | val_macro_f1=0.7037 | val_bal_acc=0.7366
# train_real_plus_synthetic | Epoch 016/100 | loss=0.0214 | train_acc=0.9908 | val_acc=0.6077 | val_macro_f1=0.6847 | val_bal_acc=0.7288
# train_real_plus_synthetic | Epoch 017/100 | loss=0.0220 | train_acc=0.9910 | val_acc=0.6110 | val_macro_f1=0.7010 | val_bal_acc=0.7402
# train_real_plus_synthetic | Epoch 018/100 | loss=0.0237 | train_acc=0.9902 | val_acc=0.6472 | val_macro_f1=0.7256 | val_bal_acc=0.7657
# train_real_plus_synthetic | Epoch 019/100 | loss=0.0158 | train_acc=0.9929 | val_acc=0.5878 | val_macro_f1=0.6773 | val_bal_acc=0.7197
# train_real_plus_synthetic | Epoch 020/100 | loss=0.0216 | train_acc=0.9911 | val_acc=0.6236 | val_macro_f1=0.7071 | val_bal_acc=0.7382
# Early stopping at epoch 20. Best val macro-F1 = 0.7345
# Saved history: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/train_real_plus_synthetic_training_history.csv
# Saved model: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/train_real_plus_synthetic_best_model.pt
#
# ----------------------------------------------------------------------
# Testing trained model on: real_plus_synthetic_train_to_real_test
# ----------------------------------------------------------------------
# Test X: (10063, 512, 6)
# Test label counts: {np.int64(1): np.int64(901), np.int64(2): np.int64(635), np.int64(3): np.int64(444), np.int64(4): np.int64(697), np.int64(5): np.int64(1363), np.int64(6): np.int64(3147), np.int64(7): np.int64(1128), np.int64(8): np.int64(1748)}
# Saved: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_plus_synthetic_train_to_real_test_confusion_matrix.png
#
# ======================================================================
# Final test results | real_plus_synthetic_train_to_real_test
# ======================================================================
# accuracy                : 0.491702
# macro_precision         : 0.527464
# macro_recall            : 0.585058
# macro_f1                : 0.531388
# weighted_precision      : 0.500482
# weighted_recall         : 0.491702
# weighted_f1             : 0.477059
# balanced_accuracy       : 0.585058
#
# Per-class metrics:
#    activity  precision    recall        f1  per_class_accuracy_same_as_recall  \
# 0         1   0.511370  0.973363  0.670489                           0.973363
# 1         2   0.678407  0.697638  0.687888                           0.697638
# 2         3   0.436528  0.759009  0.554276                           0.759009
# 3         4   0.391494  0.515065  0.444857                           0.515065
# 4         5   0.557428  0.655172  0.602361                           0.655172
# 5         6   0.396892  0.300286  0.341896                           0.300286
# 6         7   0.824916  0.434397  0.569106                           0.434397
# 7         8   0.422673  0.345538  0.380233                           0.345538
#
#    support
# 0      901
# 1      635
# 2      444
# 3      697
# 4     1363
# 5     3147
# 6     1128
# 7     1748
#
# Confusion matrix:
#         pred_1  pred_2  pred_3  pred_4  pred_5  pred_6  pred_7  pred_8
# true_1     877      16       0       0       0       7       0       1
# true_2      11     443       0       0       0      41       0     140
# true_3       0      29     337       0      19      36      23       0
# true_4      18      41      11     359     170      98       0       0
# true_5       0       0     195       7     893     215       0      53
# true_6     596      76     205     174     494     945      57     600
# true_7      42      26       0       0      14     525     490      31
# true_8     171      22      24     377      12     514      24     604
#
# Saved:
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_plus_synthetic_train_to_real_test_per_class_metrics.csv
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_plus_synthetic_train_to_real_test_confusion_matrix.csv
#   /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/real_plus_synthetic_train_to_real_test_predictions.csv
#
# ================================================================================
# ALL CNN-BiLSTM EXPERIMENTS DONE
# ================================================================================
#                                experiment hardware channel_mode  \
# 0                 real_train_to_real_test    A6000          6ch
# 1            real_train_to_synthetic_test    A6000          6ch
# 2            synthetic_train_to_real_test    A6000          6ch
# 3  real_plus_synthetic_train_to_real_test    A6000          6ch
#
#                          channels  accuracy  macro_precision  macro_recall  \
# 0  ACC_x,ACC_y,ACC_z,BVP,EDA,TEMP  0.527576         0.520254      0.563808
# 1  ACC_x,ACC_y,ACC_z,BVP,EDA,TEMP  0.541250         0.490293      0.541250
# 2  ACC_x,ACC_y,ACC_z,BVP,EDA,TEMP  0.454437         0.505343      0.526580
# 3  ACC_x,ACC_y,ACC_z,BVP,EDA,TEMP  0.491702         0.527464      0.585058
#
#    macro_f1  weighted_precision  weighted_recall  weighted_f1  \
# 0  0.532448            0.535367         0.527576     0.524904
# 1  0.483267            0.490293         0.541250     0.483267
# 2  0.470665            0.561744         0.454437     0.433980
# 3  0.531388            0.500482         0.491702     0.477059
#
#    balanced_accuracy
# 0           0.563808
# 1           0.541250
# 2           0.526580
# 3           0.585058
#
# Saved summary: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior/summary_metrics.csv
# All outputs saved in: /home/iailab42/khans1/projects/ir/results/cnnbilstm_kovae_downstream_6ch_prior

# %%
# ============================================================
# evaluate_cnnbilstm_v7_a6000_random_subject_split.py
#
# CNN-BiLSTM downstream HAR evaluation for your v7 synthetic data.
#
# Main target:
#   NVIDIA RTX A6000 48GB
#
# Channel switch:
#   CHANNEL_MODE = "6ch" -> ACC_x, ACC_y, ACC_z, BVP, EDA, TEMP
#   CHANNEL_MODE = "4ch" -> ACC_x, ACC_y, ACC_z, BVP
#
# Subject split:
#   Random subject-wise split with fixed SEED.
#   With 15 subjects:
#       Train = 10 subjects
#       Val   = 2 subjects
#       Test  = 3 subjects
#
# Input real:
#   processed_all_subjects_64hz/all_X.npy
#   processed_all_subjects_64hz/all_y.npy
#   processed_all_subjects_64hz/all_subject.npy
#
# Input synthetic:
#   all6_average_synthetic_subject_outputs/generated_subjects_all_X.npy
#   all6_average_synthetic_subject_outputs/generated_subjects_all_y.npy
#   all6_average_synthetic_subject_outputs/generated_subjects_all_subject.npy
#
# Experiments:
#   1. Real train -> Real test
#   2. Real train -> Synthetic test
#   3. Synthetic train -> Real test
#   4. Real + Synthetic train -> Real test
#
# Outputs:
#   cnnbilstm_v7_results_a6000_6ch/
#   or
#   cnnbilstm_v7_results_a6000_4ch/
# ============================================================

import copy
import random
from pathlib import Path
from contextlib import nullcontext

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    confusion_matrix,
    precision_recall_fscore_support,
)


# ============================================================
# Main switch
# ============================================================

# Choose one:
CHANNEL_MODE = "6ch"
# CHANNEL_MODE = "4ch"


# ============================================================
# Paths
# ============================================================

PROJECT_ROOT = Path("/home/iailab42/khans1/projects")

REAL_DIR = PROJECT_ROOT / "data"
SYN_DIR = PROJECT_ROOT / "data" / "synthetic"

REAL_X_PATH = REAL_DIR / "all_X.npy"
REAL_Y_PATH = REAL_DIR / "all_y.npy"
REAL_SUBJECT_PATH = REAL_DIR / "all_subject.npy"

# SYN_X_PATH = SYN_DIR / "all_X_synthetic.npy"
# SYN_Y_PATH = SYN_DIR / "all_y_synthetic.npy"
# SYN_SUBJECT_PATH = SYN_DIR / "all_subject_synthetic.npy"

SYN_X_PATH = SYN_DIR / "timevae"/ "all_X_synthetic.npy"
SYN_Y_PATH = SYN_DIR / "timevae"/ "all_y_synthetic.npy"
SYN_SUBJECT_PATH = SYN_DIR / "timevae"/ "all_subject_synthetic.npy"
SYN_METADATA_PATH = SYN_DIR / "timevae"/ "all_metadata_synthetic.csv"

# OUT_DIR = PROJECT_ROOT / "results" / f"cnnbilstm_kovae_downstream_{CHANNEL_MODE}"
OUT_DIR = PROJECT_ROOT / "results" / f"cnnbilstm_timevae_downstream_{CHANNEL_MODE}"
OUT_DIR.mkdir(parents=True, exist_ok=True)


# ============================================================
# General config
# ============================================================

SEED = 42
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

ALL_CHANNEL_NAMES = ["ACC_x", "ACC_y", "ACC_z", "BVP", "EDA", "TEMP"]

if CHANNEL_MODE == "6ch":
    CHANNEL_NAMES = ["ACC_x", "ACC_y", "ACC_z", "BVP", "EDA", "TEMP"]
elif CHANNEL_MODE == "4ch":
    CHANNEL_NAMES = ["ACC_x", "ACC_y", "ACC_z", "BVP"]
else:
    raise ValueError("CHANNEL_MODE must be '6ch' or '4ch'.")

USE_CHANNEL_INDICES = [ALL_CHANNEL_NAMES.index(ch) for ch in CHANNEL_NAMES]
NUM_CHANNELS = len(CHANNEL_NAMES)

ACTIVITY_IDS = [1, 2, 3, 4, 5, 6, 7, 8]
NUM_CLASSES = len(ACTIVITY_IDS)

WINDOW_LEN = 512

# Paper-style subsequence setup adapted to your 512-sample windows:
# paper: 128 = 4 x 32
# yours: 512 = 4 x 128
N_SEQ = 4
N_STEPS = WINDOW_LEN // N_SEQ

if WINDOW_LEN % N_SEQ != 0:
    raise ValueError("WINDOW_LEN must be divisible by N_SEQ.")

# Random subject-wise split counts.
N_TEST_SUBJECTS = 3
N_VAL_SUBJECTS = 2

# Leave empty for random split.
# Or manually set, e.g. TEST_SUBJECTS = ["S13", "S14", "S15"]
TEST_SUBJECTS = []
VAL_SUBJECTS = []


# ============================================================
# A6000 training settings
# ============================================================

BATCH_SIZE = 384
NUM_WORKERS = 6

EPOCHS_REAL_TO_REAL = 100
EPOCHS_REAL_TO_SYN = 100
EPOCHS_SYN_TO_REAL = 100
EPOCHS_REAL_PLUS_SYN_TO_REAL = 100

LR = 1e-3
WEIGHT_DECAY = 1e-4
DROPOUT = 0.5

USE_CLASS_WEIGHTS = True
USE_AMP = True
USE_TF32 = True

SAVE_CONFUSION_MATRIX_PNG = True

# Early stopping based on validation Macro-F1.
PATIENCE = 15


# ============================================================
# CUDA backend settings
# ============================================================

if DEVICE == "cuda":
    torch.backends.cuda.matmul.allow_tf32 = USE_TF32
    torch.backends.cudnn.allow_tf32 = USE_TF32

    # More reproducible. You can set True for speed, but False is safer.
    torch.backends.cudnn.benchmark = False


# ============================================================
# Reproducibility
# ============================================================

def set_seed(seed):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


set_seed(SEED)


def autocast_context():
    """
    New non-deprecated AMP autocast syntax.

    Old deprecated:
        torch.cuda.amp.autocast()

    New:
        torch.amp.autocast("cuda", enabled=True/False)
    """
    if DEVICE == "cuda":
        return torch.amp.autocast("cuda", enabled=USE_AMP)

    return nullcontext()


# ============================================================
# Label helpers
# ============================================================

LABEL_TO_INDEX = {label: i for i, label in enumerate(ACTIVITY_IDS)}
INDEX_TO_LABEL = {i: label for label, i in LABEL_TO_INDEX.items()}


def labels_to_indices(y):
    y = np.asarray(y).astype(np.int64)
    out = np.zeros_like(y, dtype=np.int64)

    for i, lab in enumerate(y):
        lab = int(lab)

        if lab not in LABEL_TO_INDEX:
            raise ValueError(f"Unexpected label {lab}. Expected labels: {ACTIVITY_IDS}")

        out[i] = LABEL_TO_INDEX[lab]

    return out


def indices_to_labels(y_idx):
    y_idx = np.asarray(y_idx).astype(np.int64)
    return np.array([INDEX_TO_LABEL[int(i)] for i in y_idx], dtype=np.int64)


# ============================================================
# File helpers
# ============================================================

def require_file(path):
    path = Path(path)

    if not path.exists():
        error_message = (
            f"\nMissing file: {path}\n"
            f"Make sure these files exist:\n"
            f"  /home/iailab42/khans1/projects/data/all_X.npy\n"
            f"  /home/iailab42/khans1/projects/data/all_y.npy\n"
            f"  /home/iailab42/khans1/projects/data/all_subject.npy\n"
            f"  /home/iailab42/khans1/projects/data/synthetic/all_X_synthetic.npy\n"
            f"  /home/iailab42/khans1/projects/data/synthetic/all_y_synthetic.npy\n"
            f"  /home/iailab42/khans1/projects/data/synthetic/all_subject_synthetic.npy\n"
        )
        raise FileNotFoundError(error_message)

    return path


# ============================================================
# Load data
# ============================================================

def load_data(x_path, y_path, subject_path, name):
    require_file(x_path)
    require_file(y_path)
    require_file(subject_path)

    X = np.load(x_path).astype(np.float32)
    y = np.load(y_path).astype(np.int64)
    subjects = np.load(subject_path, allow_pickle=True).astype(str)

    if X.ndim != 3:
        raise ValueError(f"{name} X should be [N, T, C], got {X.shape}")

    if X.shape[1] != WINDOW_LEN:
        raise ValueError(
            f"{name} expected window length {WINDOW_LEN}, got {X.shape[1]}"
        )

    if X.shape[2] != len(ALL_CHANNEL_NAMES):
        raise ValueError(
            f"{name} expected original 6 channels, got {X.shape[2]}"
        )

    if len(X) != len(y):
        raise ValueError(f"{name} X/y mismatch: {len(X)} vs {len(y)}")

    if len(y) != len(subjects):
        raise ValueError(f"{name} y/subjects mismatch: {len(y)} vs {len(subjects)}")

    keep = np.isin(y, np.array(ACTIVITY_IDS, dtype=np.int64))

    X = X[keep]
    y = y[keep]
    subjects = subjects[keep]

    # Channel switch happens here.
    X = X[:, :, USE_CHANNEL_INDICES].astype(np.float32)

    print("\n" + "=" * 70)
    print(f"Loaded {name}")
    print("=" * 70)
    print("X:", X.shape)
    print("y:", y.shape)
    print("subjects:", subjects.shape)
    print("CHANNEL_MODE:", CHANNEL_MODE)
    print("Using channels:", CHANNEL_NAMES)
    print("Label counts:", dict(zip(*np.unique(y, return_counts=True))))
    print("Subject counts:", dict(zip(*np.unique(subjects, return_counts=True))))

    return X, y, subjects


def load_real_data():
    return load_data(
        REAL_X_PATH,
        REAL_Y_PATH,
        REAL_SUBJECT_PATH,
        name="real data",
    )


def load_synthetic_data():
    return load_data(
        SYN_X_PATH,
        SYN_Y_PATH,
        SYN_SUBJECT_PATH,
        name="synthetic data",
    )


# ============================================================
# Subject split
# ============================================================

def subject_sort_key(s):
    s = str(s)

    if s.startswith("S"):
        try:
            return int(s[1:])
        except Exception:
            return s

    return s


def make_subject_split(real_subjects):
    unique_subjects = sorted(np.unique(real_subjects).astype(str), key=subject_sort_key)

    if len(unique_subjects) < (N_TEST_SUBJECTS + N_VAL_SUBJECTS + 1):
        raise ValueError(
            f"Not enough real subjects for split. Found: {unique_subjects}"
        )

    # Manual split if user fills TEST_SUBJECTS / VAL_SUBJECTS.
    if len(TEST_SUBJECTS) > 0 or len(VAL_SUBJECTS) > 0:
        if len(TEST_SUBJECTS) == 0 or len(VAL_SUBJECTS) == 0:
            raise ValueError(
                "If using manual split, set both TEST_SUBJECTS and VAL_SUBJECTS."
            )

        test_subjects = list(TEST_SUBJECTS)
        val_subjects = list(VAL_SUBJECTS)

        train_subjects = [
            s for s in unique_subjects
            if s not in test_subjects and s not in val_subjects
        ]

        split_mode = "manual"

    else:
        # Fixed random subject split.
        rng = np.random.default_rng(SEED)
        shuffled_subjects = np.array(unique_subjects, dtype=object)
        rng.shuffle(shuffled_subjects)
        shuffled_subjects = shuffled_subjects.tolist()

        test_subjects = shuffled_subjects[:N_TEST_SUBJECTS]
        val_subjects = shuffled_subjects[
            N_TEST_SUBJECTS:N_TEST_SUBJECTS + N_VAL_SUBJECTS
        ]
        train_subjects = shuffled_subjects[N_TEST_SUBJECTS + N_VAL_SUBJECTS:]

        split_mode = f"random_fixed_seed_{SEED}"

    train_subjects = sorted(train_subjects, key=subject_sort_key)
    val_subjects = sorted(val_subjects, key=subject_sort_key)
    test_subjects = sorted(test_subjects, key=subject_sort_key)

    if len(set(train_subjects) & set(val_subjects)) > 0:
        raise ValueError("Train/val subject overlap detected.")

    if len(set(train_subjects) & set(test_subjects)) > 0:
        raise ValueError("Train/test subject overlap detected.")

    if len(set(val_subjects) & set(test_subjects)) > 0:
        raise ValueError("Val/test subject overlap detected.")

    print("\n" + "=" * 70)
    print("Real subject split")
    print("=" * 70)
    print("Split mode:     ", split_mode)
    print("Train subjects: ", train_subjects)
    print("Val subjects:   ", val_subjects)
    print("Test subjects:  ", test_subjects)
    print("Train % by subject:", len(train_subjects) / len(unique_subjects) * 100.0)
    print("Val % by subject:  ", len(val_subjects) / len(unique_subjects) * 100.0)
    print("Test % by subject: ", len(test_subjects) / len(unique_subjects) * 100.0)

    split_df = pd.DataFrame({
        "split": ["train", "val", "test"],
        "subjects": [
            ",".join(train_subjects),
            ",".join(val_subjects),
            ",".join(test_subjects),
        ],
        "num_subjects": [
            len(train_subjects),
            len(val_subjects),
            len(test_subjects),
        ],
        "percentage_by_subject": [
            len(train_subjects) / len(unique_subjects) * 100.0,
            len(val_subjects) / len(unique_subjects) * 100.0,
            len(test_subjects) / len(unique_subjects) * 100.0,
        ],
        "split_mode": [split_mode, split_mode, split_mode],
        "seed": [SEED, SEED, SEED],
    })

    split_df.to_csv(OUT_DIR / "real_subject_split.csv", index=False)

    return train_subjects, val_subjects, test_subjects


def filter_by_subjects(X, y, subjects, selected_subjects):
    selected_subjects = set([str(s) for s in selected_subjects])
    mask = np.array([str(s) in selected_subjects for s in subjects], dtype=bool)

    return X[mask], y[mask], subjects[mask]


# ============================================================
# Dataset / DataLoader
# ============================================================

class HARWindowDataset(Dataset):
    def __init__(self, X, y_original):
        X = np.asarray(X, dtype=np.float32)
        y_original = np.asarray(y_original, dtype=np.int64)
        y_idx = labels_to_indices(y_original)

        if X.ndim != 3:
            raise ValueError(f"Expected X [N,T,C], got {X.shape}")

        if X.shape[1] != WINDOW_LEN:
            raise ValueError(f"Expected window length {WINDOW_LEN}, got {X.shape[1]}")

        if X.shape[2] != NUM_CHANNELS:
            raise ValueError(f"Expected {NUM_CHANNELS} channels, got {X.shape[2]}")

        self.X = torch.from_numpy(X)
        self.y = torch.from_numpy(y_idx).long()
        self.y_original = y_original

    def __len__(self):
        return len(self.y)

    def __getitem__(self, idx):
        return self.X[idx], self.y[idx]


def make_loader(X, y, batch_size, shuffle):
    dataset = HARWindowDataset(X, y)

    # Avoid BatchNorm crash from final train batch of size 1.
    drop_last = bool(shuffle and len(dataset) > batch_size)

    loader = DataLoader(
        dataset,
        batch_size=batch_size,
        shuffle=shuffle,
        num_workers=NUM_WORKERS,
        pin_memory=torch.cuda.is_available(),
        drop_last=drop_last,
        persistent_workers=(NUM_WORKERS > 0),
    )

    return loader


def compute_class_weights(y_original):
    y_idx = labels_to_indices(y_original)
    counts = np.bincount(y_idx, minlength=NUM_CLASSES).astype(np.float32)

    counts = np.maximum(counts, 1.0)

    weights = counts.sum() / (NUM_CLASSES * counts)
    weights = weights / weights.mean()

    return torch.tensor(weights, dtype=torch.float32)


# ============================================================
# CNN-BiLSTM model
# ============================================================

class TimeDistributedConvBranch(nn.Module):
    def __init__(self, in_channels, kernel_size, dropout):
        super().__init__()

        padding = kernel_size // 2

        self.net = nn.Sequential(
            nn.Conv1d(
                in_channels=in_channels,
                out_channels=64,
                kernel_size=kernel_size,
                padding=padding,
            ),
            nn.ReLU(inplace=True),

            nn.Conv1d(
                in_channels=64,
                out_channels=32,
                kernel_size=kernel_size,
                padding=padding,
            ),
            nn.ReLU(inplace=True),

            nn.Dropout(dropout),
            nn.MaxPool1d(kernel_size=2),
        )

    def forward(self, x):
        # x: [B, S, steps, C]
        B, S, steps, C = x.shape

        # TimeDistributed Conv1D:
        # [B, S, steps, C] -> [B*S, C, steps]
        x = x.reshape(B * S, steps, C)
        x = x.transpose(1, 2)

        h = self.net(x)

        # h: [B*S, 32, steps/2]
        h = h.reshape(B, S, -1)

        return h


class MultiBranchCNNBiLSTM(nn.Module):
    def __init__(
        self,
        num_channels,
        num_classes,
        n_seq,
        n_steps,
        dropout,
    ):
        super().__init__()

        self.num_channels = num_channels
        self.num_classes = num_classes
        self.n_seq = n_seq
        self.n_steps = n_steps

        self.branch_k3 = TimeDistributedConvBranch(
            in_channels=num_channels,
            kernel_size=3,
            dropout=dropout,
        )

        self.branch_k7 = TimeDistributedConvBranch(
            in_channels=num_channels,
            kernel_size=7,
            dropout=dropout,
        )

        self.branch_k11 = TimeDistributedConvBranch(
            in_channels=num_channels,
            kernel_size=11,
            dropout=dropout,
        )

        branch_out_dim = 32 * (n_steps // 2)
        lstm_input_dim = branch_out_dim * 3

        self.bilstm1 = nn.LSTM(
            input_size=lstm_input_dim,
            hidden_size=64,
            batch_first=True,
            bidirectional=True,
        )

        self.bilstm2 = nn.LSTM(
            input_size=64 * 2,
            hidden_size=32,
            batch_first=True,
            bidirectional=True,
        )

        self.fc = nn.Linear(32 * 2, 128)
        self.bn = nn.BatchNorm1d(128)
        self.dropout = nn.Dropout(dropout)
        self.classifier = nn.Linear(128, num_classes)

    def forward(self, x):
        # x: [B, 512, C]
        B, T, C = x.shape

        expected_t = self.n_seq * self.n_steps

        if T != expected_t:
            raise ValueError(f"Expected T={expected_t}, got T={T}")

        if C != self.num_channels:
            raise ValueError(f"Expected C={self.num_channels}, got C={C}")

        # [B, 512, C] -> [B, 4, 128, C]
        x = x.reshape(B, self.n_seq, self.n_steps, C)

        h3 = self.branch_k3(x)
        h7 = self.branch_k7(x)
        h11 = self.branch_k11(x)

        h = torch.cat([h3, h7, h11], dim=-1)

        h, _ = self.bilstm1(h)
        h, (h_n, _) = self.bilstm2(h)

        # h_n shape: [num_layers * num_directions, B, hidden]
        # last forward = h_n[-2], last backward = h_n[-1]
        h_final = torch.cat([h_n[-2], h_n[-1]], dim=1)

        z = self.fc(h_final)
        z = self.bn(z)
        z = F.relu(z)
        z = self.dropout(z)

        logits = self.classifier(z)

        return logits


def make_new_model():
    model = MultiBranchCNNBiLSTM(
        num_channels=NUM_CHANNELS,
        num_classes=NUM_CLASSES,
        n_seq=N_SEQ,
        n_steps=N_STEPS,
        dropout=DROPOUT,
    )

    return model


# ============================================================
# Metrics
# ============================================================

def evaluate_model(model, loader):
    model.eval()

    all_true = []
    all_pred = []
    all_prob = []

    with torch.no_grad():
        for X_batch, y_batch in loader:
            X_batch = X_batch.to(DEVICE, non_blocking=True)
            y_batch = y_batch.to(DEVICE, non_blocking=True)

            with autocast_context():
                logits = model(X_batch)

            probs = torch.softmax(logits.float(), dim=1)
            pred = torch.argmax(probs, dim=1)

            all_true.append(y_batch.cpu().numpy())
            all_pred.append(pred.cpu().numpy())
            all_prob.append(probs.cpu().numpy())

    y_true_idx = np.concatenate(all_true)
    y_pred_idx = np.concatenate(all_pred)
    y_prob = np.concatenate(all_prob)

    y_true = indices_to_labels(y_true_idx)
    y_pred = indices_to_labels(y_pred_idx)

    return y_true, y_pred, y_prob


def compute_metrics(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=np.int64)
    y_pred = np.asarray(y_pred, dtype=np.int64)

    accuracy = accuracy_score(y_true, y_pred)

    macro_precision = precision_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="macro",
        zero_division=0,
    )

    macro_recall = recall_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="macro",
        zero_division=0,
    )

    macro_f1 = f1_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="macro",
        zero_division=0,
    )

    weighted_precision = precision_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="weighted",
        zero_division=0,
    )

    weighted_recall = recall_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="weighted",
        zero_division=0,
    )

    weighted_f1 = f1_score(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        average="weighted",
        zero_division=0,
    )

    # Balanced accuracy for multiclass = average recall across classes.
    # This is intentionally same definition as macro recall.
    balanced_accuracy = macro_recall

    metrics = {
        "accuracy": accuracy,
        "macro_precision": macro_precision,
        "macro_recall": macro_recall,
        "macro_f1": macro_f1,
        "weighted_precision": weighted_precision,
        "weighted_recall": weighted_recall,
        "weighted_f1": weighted_f1,
        "balanced_accuracy": balanced_accuracy,
    }

    return metrics


def compute_per_class_metrics(y_true, y_pred):
    y_true = np.asarray(y_true, dtype=np.int64)
    y_pred = np.asarray(y_pred, dtype=np.int64)

    precision, recall, f1, support = precision_recall_fscore_support(
        y_true,
        y_pred,
        labels=ACTIVITY_IDS,
        zero_division=0,
    )

    cm = confusion_matrix(y_true, y_pred, labels=ACTIVITY_IDS)

    row_sum = cm.sum(axis=1)
    diag = np.diag(cm)

    per_class_accuracy = np.divide(
        diag,
        row_sum,
        out=np.zeros_like(diag, dtype=np.float64),
        where=row_sum != 0,
    )

    rows = []

    for i, act in enumerate(ACTIVITY_IDS):
        rows.append({
            "activity": act,
            "precision": float(precision[i]),
            "recall": float(recall[i]),
            "f1": float(f1[i]),
            "per_class_accuracy_same_as_recall": float(per_class_accuracy[i]),
            "support": int(support[i]),
        })

    per_class_df = pd.DataFrame(rows)

    return per_class_df, cm


# ============================================================
# Plot / save results
# ============================================================

def save_confusion_matrix_png(cm, experiment_name):
    fig, ax = plt.subplots(figsize=(8, 7))

    im = ax.imshow(cm, interpolation="nearest")
    fig.colorbar(im, ax=ax)

    ax.set_title(f"Confusion Matrix | {experiment_name}")
    ax.set_xlabel("Predicted activity")
    ax.set_ylabel("True activity")

    tick_marks = np.arange(len(ACTIVITY_IDS))
    ax.set_xticks(tick_marks)
    ax.set_yticks(tick_marks)
    ax.set_xticklabels([str(a) for a in ACTIVITY_IDS])
    ax.set_yticklabels([str(a) for a in ACTIVITY_IDS])

    threshold = cm.max() / 2.0 if cm.max() > 0 else 0.5

    for i in range(cm.shape[0]):
        for j in range(cm.shape[1]):
            value = int(cm[i, j])
            ax.text(
                j,
                i,
                str(value),
                ha="center",
                va="center",
                color="white" if value > threshold else "black",
                fontsize=9,
            )

    plt.tight_layout()

    save_path = OUT_DIR / f"{experiment_name}_confusion_matrix.png"
    plt.savefig(save_path, dpi=150)
    plt.close()

    print("Saved:", save_path)


def save_final_results(model, test_loader, experiment_name):
    y_true, y_pred, y_prob = evaluate_model(model, test_loader)

    metrics = compute_metrics(y_true, y_pred)
    per_class_df, cm = compute_per_class_metrics(y_true, y_pred)

    cm_df = pd.DataFrame(
        cm,
        index=[f"true_{a}" for a in ACTIVITY_IDS],
        columns=[f"pred_{a}" for a in ACTIVITY_IDS],
    )

    pred_df = pd.DataFrame({
        "y_true": y_true,
        "y_pred": y_pred,
        "correct": y_true == y_pred,
    })

    for i, act in enumerate(ACTIVITY_IDS):
        pred_df[f"prob_activity_{act}"] = y_prob[:, i]

    per_class_path = OUT_DIR / f"{experiment_name}_per_class_metrics.csv"
    cm_path = OUT_DIR / f"{experiment_name}_confusion_matrix.csv"
    pred_path = OUT_DIR / f"{experiment_name}_predictions.csv"

    per_class_df.to_csv(per_class_path, index=False)
    cm_df.to_csv(cm_path)
    pred_df.to_csv(pred_path, index=False)

    if SAVE_CONFUSION_MATRIX_PNG:
        save_confusion_matrix_png(cm, experiment_name)

    print("\n" + "=" * 70)
    print(f"Final test results | {experiment_name}")
    print("=" * 70)

    for k, v in metrics.items():
        print(f"{k:24s}: {v:.6f}")

    print("\nPer-class metrics:")
    print(per_class_df)

    print("\nConfusion matrix:")
    print(cm_df)

    print("\nSaved:")
    print(" ", per_class_path)
    print(" ", cm_path)
    print(" ", pred_path)

    summary_row = {
        "experiment": experiment_name,
        "hardware": "A6000",
        "channel_mode": CHANNEL_MODE,
        "channels": ",".join(CHANNEL_NAMES),
        **metrics,
    }

    return summary_row


# ============================================================
# Training
# ============================================================

def train_model(
    model,
    train_loader,
    val_loader,
    y_train_original,
    epochs,
    lr,
    experiment_name,
):
    model = model.to(DEVICE)

    if USE_CLASS_WEIGHTS:
        class_weights = compute_class_weights(y_train_original).to(DEVICE)

        print("\nClass weights:")
        for act, w in zip(ACTIVITY_IDS, class_weights.detach().cpu().numpy()):
            print(f"  Activity {act}: {w:.4f}")

        criterion = nn.CrossEntropyLoss(weight=class_weights)
    else:
        criterion = nn.CrossEntropyLoss()

    optimizer = torch.optim.Adam(
        model.parameters(),
        lr=lr,
        weight_decay=WEIGHT_DECAY,
    )

    # New non-deprecated GradScaler syntax.
    scaler = torch.amp.GradScaler(
        "cuda",
        enabled=(USE_AMP and DEVICE == "cuda"),
    )

    best_val_macro_f1 = -1.0
    best_state = None
    epochs_without_improvement = 0

    history_rows = []

    for epoch in range(1, epochs + 1):
        model.train()

        total_loss = 0.0
        total_correct = 0
        total_seen = 0

        for X_batch, y_batch in train_loader:
            X_batch = X_batch.to(DEVICE, non_blocking=True)
            y_batch = y_batch.to(DEVICE, non_blocking=True)

            optimizer.zero_grad(set_to_none=True)

            with autocast_context():
                logits = model(X_batch)
                loss = criterion(logits, y_batch)

            scaler.scale(loss).backward()
            scaler.step(optimizer)
            scaler.update()

            with torch.no_grad():
                pred = torch.argmax(logits, dim=1)
                correct = (pred == y_batch).sum().item()

            bs = len(y_batch)
            total_loss += loss.item() * bs
            total_correct += correct
            total_seen += bs

        train_loss = total_loss / max(total_seen, 1)
        train_accuracy = total_correct / max(total_seen, 1)

        val_true, val_pred, _ = evaluate_model(model, val_loader)
        val_metrics = compute_metrics(val_true, val_pred)

        row = {
            "epoch": epoch,
            "train_loss": train_loss,
            "train_accuracy": train_accuracy,
            "val_accuracy": val_metrics["accuracy"],
            "val_macro_precision": val_metrics["macro_precision"],
            "val_macro_recall": val_metrics["macro_recall"],
            "val_macro_f1": val_metrics["macro_f1"],
            "val_balanced_accuracy": val_metrics["balanced_accuracy"],
        }

        history_rows.append(row)

        print(
            f"{experiment_name} | "
            f"Epoch {epoch:03d}/{epochs} | "
            f"loss={train_loss:.4f} | "
            f"train_acc={train_accuracy:.4f} | "
            f"val_acc={val_metrics['accuracy']:.4f} | "
            f"val_macro_f1={val_metrics['macro_f1']:.4f} | "
            f"val_bal_acc={val_metrics['balanced_accuracy']:.4f}",
            flush=True,
        )

        if val_metrics["macro_f1"] > best_val_macro_f1:
            best_val_macro_f1 = val_metrics["macro_f1"]
            best_state = copy.deepcopy(model.state_dict())
            epochs_without_improvement = 0
        else:
            epochs_without_improvement += 1

        if epochs_without_improvement >= PATIENCE:
            print(
                f"Early stopping at epoch {epoch}. "
                f"Best val macro-F1 = {best_val_macro_f1:.4f}"
            )
            break

    if best_state is not None:
        model.load_state_dict(best_state)

    history_df = pd.DataFrame(history_rows)
    history_path = OUT_DIR / f"{experiment_name}_training_history.csv"
    history_df.to_csv(history_path, index=False)

    model_path = OUT_DIR / f"{experiment_name}_best_model.pt"

    torch.save(
        {
            "model_state_dict": model.state_dict(),
            "hardware": "A6000",
            "channel_mode": CHANNEL_MODE,
            "channels": CHANNEL_NAMES,
            "activity_ids": ACTIVITY_IDS,
            "window_len": WINDOW_LEN,
            "n_seq": N_SEQ,
            "n_steps": N_STEPS,
            "best_val_macro_f1": best_val_macro_f1,
            "batch_size": BATCH_SIZE,
            "use_amp": USE_AMP,
            "use_tf32": USE_TF32,
            "seed": SEED,
        },
        model_path,
    )

    print("Saved history:", history_path)
    print("Saved model:", model_path)

    return model, history_df


# ============================================================
# Experiment runner
# ============================================================

def train_once_and_evaluate(
    experiment_train_name,
    X_train,
    y_train,
    X_val,
    y_val,
    test_sets,
    epochs,
):
    print("\n" + "#" * 80)
    print(f"Training: {experiment_train_name}")
    print("#" * 80)
    print("Train X:", X_train.shape)
    print("Val X:  ", X_val.shape)
    print("Train label counts:", dict(zip(*np.unique(y_train, return_counts=True))))
    print("Val label counts:  ", dict(zip(*np.unique(y_val, return_counts=True))))

    train_loader = make_loader(
        X_train,
        y_train,
        batch_size=BATCH_SIZE,
        shuffle=True,
    )

    val_loader = make_loader(
        X_val,
        y_val,
        batch_size=BATCH_SIZE,
        shuffle=False,
    )

    model = make_new_model()

    model, history_df = train_model(
        model=model,
        train_loader=train_loader,
        val_loader=val_loader,
        y_train_original=y_train,
        epochs=epochs,
        lr=LR,
        experiment_name=experiment_train_name,
    )

    summary_rows = []

    for test_name, X_test, y_test in test_sets:
        print("\n" + "-" * 70)
        print(f"Testing trained model on: {test_name}")
        print("-" * 70)
        print("Test X:", X_test.shape)
        print("Test label counts:", dict(zip(*np.unique(y_test, return_counts=True))))

        test_loader = make_loader(
            X_test,
            y_test,
            batch_size=BATCH_SIZE,
            shuffle=False,
        )

        summary_row = save_final_results(
            model=model,
            test_loader=test_loader,
            experiment_name=test_name,
        )

        summary_rows.append(summary_row)

    return summary_rows


# ============================================================
# Main
# ============================================================

def main():
    print("=" * 80)
    print("CNN-BiLSTM v7 downstream evaluation | A6000 version")
    print("=" * 80)
    print("Device:", DEVICE)

    if DEVICE == "cuda":
        print("GPU:", torch.cuda.get_device_name(0))

    print("CHANNEL_MODE:", CHANNEL_MODE)
    print("Using channels:", CHANNEL_NAMES)
    print("NUM_CHANNELS:", NUM_CHANNELS)
    print("BATCH_SIZE:", BATCH_SIZE)
    print("NUM_WORKERS:", NUM_WORKERS)
    print("USE_AMP:", USE_AMP)
    print("USE_TF32:", USE_TF32)
    print("SEED:", SEED)
    print("Output directory:", OUT_DIR)

    # ------------------------------------------------------------
    # Load data
    # ------------------------------------------------------------

    real_X, real_y, real_subjects = load_real_data()
    syn_X, syn_y, syn_subjects = load_synthetic_data()

    # ------------------------------------------------------------
    # Split real subjects
    # ------------------------------------------------------------

    train_subjects, val_subjects, test_subjects = make_subject_split(real_subjects)

    X_real_train, y_real_train, sub_real_train = filter_by_subjects(
        real_X,
        real_y,
        real_subjects,
        train_subjects,
    )

    X_real_val, y_real_val, sub_real_val = filter_by_subjects(
        real_X,
        real_y,
        real_subjects,
        val_subjects,
    )

    X_real_test, y_real_test, sub_real_test = filter_by_subjects(
        real_X,
        real_y,
        real_subjects,
        test_subjects,
    )

    print("\n" + "=" * 70)
    print("Final real split sizes")
    print("=" * 70)
    print("Real train:", X_real_train.shape)
    print("Real val:  ", X_real_val.shape)
    print("Real test: ", X_real_test.shape)
    print("Synthetic: ", syn_X.shape)

    split_size_df = pd.DataFrame([
        {
            "split": "real_train",
            "num_windows": len(X_real_train),
            "subjects": ",".join(train_subjects),
        },
        {
            "split": "real_val",
            "num_windows": len(X_real_val),
            "subjects": ",".join(val_subjects),
        },
        {
            "split": "real_test",
            "num_windows": len(X_real_test),
            "subjects": ",".join(test_subjects),
        },
        {
            "split": "synthetic_all",
            "num_windows": len(syn_X),
            "subjects": ",".join(sorted(np.unique(syn_subjects).astype(str))),
        },
    ])

    split_size_df.to_csv(OUT_DIR / "data_split_summary.csv", index=False)

    summary_rows = []

    # ------------------------------------------------------------
    # 1 and 2:
    # Train on real train subjects.
    # Test on real test subjects and synthetic data.
    # ------------------------------------------------------------

    summary_rows.extend(
        train_once_and_evaluate(
            experiment_train_name="train_real",
            X_train=X_real_train,
            y_train=y_real_train,
            X_val=X_real_val,
            y_val=y_real_val,
            test_sets=[
                ("real_train_to_real_test", X_real_test, y_real_test),
                ("real_train_to_synthetic_test", syn_X, syn_y),
            ],
            epochs=EPOCHS_REAL_TO_REAL,
        )
    )

    # ------------------------------------------------------------
    # 3:
    # Train on synthetic.
    # Test on real test subjects.
    #
    # Real validation is used for early stopping only.
    # ------------------------------------------------------------

    summary_rows.extend(
        train_once_and_evaluate(
            experiment_train_name="train_synthetic",
            X_train=syn_X,
            y_train=syn_y,
            X_val=X_real_val,
            y_val=y_real_val,
            test_sets=[
                ("synthetic_train_to_real_test", X_real_test, y_real_test),
            ],
            epochs=EPOCHS_SYN_TO_REAL,
        )
    )

    # ------------------------------------------------------------
    # 4:
    # Train on real train subjects + synthetic.
    # Test on real test subjects.
    # ------------------------------------------------------------

    X_real_plus_syn = np.concatenate([X_real_train, syn_X], axis=0).astype(np.float32)
    y_real_plus_syn = np.concatenate([y_real_train, syn_y], axis=0).astype(np.int64)

    summary_rows.extend(
        train_once_and_evaluate(
            experiment_train_name="train_real_plus_synthetic",
            X_train=X_real_plus_syn,
            y_train=y_real_plus_syn,
            X_val=X_real_val,
            y_val=y_real_val,
            test_sets=[
                ("real_plus_synthetic_train_to_real_test", X_real_test, y_real_test),
            ],
            epochs=EPOCHS_REAL_PLUS_SYN_TO_REAL,
        )
    )

    # ------------------------------------------------------------
    # Save summary
    # ------------------------------------------------------------

    summary_df = pd.DataFrame(summary_rows)

    metric_cols = [
        "accuracy",
        "macro_precision",
        "macro_recall",
        "macro_f1",
        "weighted_precision",
        "weighted_recall",
        "weighted_f1",
        "balanced_accuracy",
    ]

    first_cols = [
        "experiment",
        "hardware",
        "channel_mode",
        "channels",
    ]

    summary_df = summary_df[first_cols + metric_cols]

    summary_path = OUT_DIR / "summary_metrics.csv"
    summary_df.to_csv(summary_path, index=False)

    print("\n" + "=" * 80)
    print("ALL CNN-BiLSTM EXPERIMENTS DONE")
    print("=" * 80)
    print(summary_df)
    print("\nSaved summary:", summary_path)
    print("All outputs saved in:", OUT_DIR)


if __name__ == "__main__":
    main()
# Out:
# ================================================================================
# CNN-BiLSTM v7 downstream evaluation | A6000 version
# ================================================================================
# Device: cuda
# GPU: NVIDIA RTX A6000
# CHANNEL_MODE: 6ch
# Using channels: ['ACC_x', 'ACC_y', 'ACC_z', 'BVP', 'EDA', 'TEMP']
# NUM_CHANNELS: 6
# BATCH_SIZE: 384
# NUM_WORKERS: 6
# USE_AMP: True
# USE_TF32: True
# SEED: 42
# Output directory: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch
#
# ======================================================================
# Loaded real data
# ======================================================================
# X: (46907, 512, 6)
# y: (46907,)
# subjects: (46907,)
# CHANNEL_MODE: 6ch
# Using channels: ['ACC_x', 'ACC_y', 'ACC_z', 'BVP', 'EDA', 'TEMP']
# Label counts: {np.int64(1): np.int64(4534), np.int64(2): np.int64(3205), np.int64(3): np.int64(2277), np.int64(4): np.int64(3439), np.int64(5): np.int64(6807), np.int64(6): np.int64(13518), np.int64(7): np.int64(4660), np.int64(8): np.int64(8467)}
# Subject counts: {np.str_('S1'): np.int64(3445), np.str_('S10'): np.int64(3532), np.str_('S11'): np.int64(3487), np.str_('S12'): np.int64(2938), np.str_('S13'): np.int64(3356), np.str_('S14'): np.int64(3177), np.str_('S15'): np.int64(2919), np.str_('S2'): np.int64(2818), np.str_('S3'): np.int64(3344), np.str_('S4'): np.int64(3295), np.str_('S5'): np.int64(3345), np.str_('S6'): np.int64(1463), np.str_('S7'): np.int64(3553), np.str_('S8'): np.int64(2978), np.str_('S9'): np.int64(3257)}
#
# ======================================================================
# Loaded synthetic data
# ======================================================================
# X: (46907, 512, 6)
# y: (46907,)
# subjects: (46907,)
# CHANNEL_MODE: 6ch
# Using channels: ['ACC_x', 'ACC_y', 'ACC_z', 'BVP', 'EDA', 'TEMP']
# Label counts: {np.int64(1): np.int64(4534), np.int64(2): np.int64(3205), np.int64(3): np.int64(2277), np.int64(4): np.int64(3439), np.int64(5): np.int64(6807), np.int64(6): np.int64(13518), np.int64(7): np.int64(4660), np.int64(8): np.int64(8467)}
# Subject counts: {np.str_('SYN_001'): np.int64(1524), np.str_('SYN_002'): np.int64(1566), np.str_('SYN_003'): np.int64(1612), np.str_('SYN_004'): np.int64(1565), np.str_('SYN_005'): np.int64(1530), np.str_('SYN_006'): np.int64(1588), np.str_('SYN_007'): np.int64(1500), np.str_('SYN_008'): np.int64(1596), np.str_('SYN_009'): np.int64(1584), np.str_('SYN_010'): np.int64(1535), np.str_('SYN_011'): np.int64(1615), np.str_('SYN_012'): np.int64(1537), np.str_('SYN_013'): np.int64(1623), np.str_('SYN_014'): np.int64(1498), np.str_('SYN_015'): np.int64(1484), np.str_('SYN_016'): np.int64(1591), np.str_('SYN_017'): np.int64(1483), np.str_('SYN_018'): np.int64(1545), np.str_('SYN_019'): np.int64(1583), np.str_('SYN_020'): np.int64(1601), np.str_('SYN_021'): np.int64(1559), np.str_('SYN_022'): np.int64(1593), np.str_('SYN_023'): np.int64(1572), np.str_('SYN_024'): np.int64(1610), np.str_('SYN_025'): np.int64(1567), np.str_('SYN_026'): np.int64(1574), np.str_('SYN_027'): np.int64(1572), np.str_('SYN_028'): np.int64(1591), np.str_('SYN_029'): np.int64(1545), np.str_('SYN_030'): np.int64(1564)}
#
# ======================================================================
# Real subject split
# ======================================================================
# Split mode:      random_fixed_seed_42
# Train subjects:  [np.str_('S2'), np.str_('S3'), np.str_('S5'), np.str_('S6'), np.str_('S9'), np.str_('S11'), np.str_('S12'), np.str_('S13'), np.str_('S14'), np.str_('S15')]
# Val subjects:    [np.str_('S1'), np.str_('S4')]
# Test subjects:   [np.str_('S7'), np.str_('S8'), np.str_('S10')]
# Train % by subject: 66.66666666666666
# Val % by subject:   13.333333333333334
# Test % by subject:  20.0
#
# ======================================================================
# Final real split sizes
# ======================================================================
# Real train: (30104, 512, 6)
# Real val:   (6740, 512, 6)
# Real test:  (10063, 512, 6)
# Synthetic:  (46907, 512, 6)
#
# ################################################################################
# Training: train_real
# ################################################################################
# Train X: (30104, 512, 6)
# Val X:   (6740, 512, 6)
# Train label counts: {np.int64(1): np.int64(3004), np.int64(2): np.int64(2170), np.int64(3): np.int64(1502), np.int64(4): np.int64(2304), np.int64(5): np.int64(4501), np.int64(6): np.int64(8251), np.int64(7): np.int64(2862), np.int64(8): np.int64(5510)}
# Val label counts:   {np.int64(1): np.int64(629), np.int64(2): np.int64(400), np.int64(3): np.int64(331), np.int64(4): np.int64(438), np.int64(5): np.int64(943), np.int64(6): np.int64(2120), np.int64(7): np.int64(670), np.int64(8): np.int64(1209)}
#
# Class weights:
#   Activity 1: 0.9622
#   Activity 2: 1.3320
#   Activity 3: 1.9244
#   Activity 4: 1.2545
#   Activity 5: 0.6422
#   Activity 6: 0.3503
#   Activity 7: 1.0099
#   Activity 8: 0.5246
# train_real | Epoch 001/100 | loss=0.8033 | train_acc=0.6774 | val_acc=0.5993 | val_macro_f1=0.6660 | val_bal_acc=0.7257
# train_real | Epoch 002/100 | loss=0.3447 | train_acc=0.8398 | val_acc=0.5877 | val_macro_f1=0.6805 | val_bal_acc=0.7287
# train_real | Epoch 003/100 | loss=0.2190 | train_acc=0.8972 | val_acc=0.5717 | val_macro_f1=0.6418 | val_bal_acc=0.7027
# train_real | Epoch 004/100 | loss=0.1686 | train_acc=0.9190 | val_acc=0.5567 | val_macro_f1=0.6270 | val_bal_acc=0.6917
# train_real | Epoch 005/100 | loss=0.1221 | train_acc=0.9415 | val_acc=0.5638 | val_macro_f1=0.6509 | val_bal_acc=0.6961
# train_real | Epoch 006/100 | loss=0.0760 | train_acc=0.9644 | val_acc=0.6079 | val_macro_f1=0.7037 | val_bal_acc=0.7345
# train_real | Epoch 007/100 | loss=0.0782 | train_acc=0.9629 | val_acc=0.5896 | val_macro_f1=0.6711 | val_bal_acc=0.7082
# train_real | Epoch 008/100 | loss=0.0664 | train_acc=0.9684 | val_acc=0.5622 | val_macro_f1=0.6354 | val_bal_acc=0.6928
# train_real | Epoch 009/100 | loss=0.0546 | train_acc=0.9747 | val_acc=0.5807 | val_macro_f1=0.6569 | val_bal_acc=0.6869
# train_real | Epoch 010/100 | loss=0.0441 | train_acc=0.9795 | val_acc=0.6174 | val_macro_f1=0.6998 | val_bal_acc=0.7393
# train_real | Epoch 011/100 | loss=0.0398 | train_acc=0.9818 | val_acc=0.5280 | val_macro_f1=0.6055 | val_bal_acc=0.6582
# train_real | Epoch 012/100 | loss=0.0503 | train_acc=0.9765 | val_acc=0.5840 | val_macro_f1=0.6406 | val_bal_acc=0.6888
# train_real | Epoch 013/100 | loss=0.0402 | train_acc=0.9813 | val_acc=0.6353 | val_macro_f1=0.7198 | val_bal_acc=0.7541
# train_real | Epoch 014/100 | loss=0.0354 | train_acc=0.9852 | val_acc=0.6157 | val_macro_f1=0.6822 | val_bal_acc=0.7224
# train_real | Epoch 015/100 | loss=0.0312 | train_acc=0.9864 | val_acc=0.6217 | val_macro_f1=0.6749 | val_bal_acc=0.7048
# train_real | Epoch 016/100 | loss=0.0263 | train_acc=0.9888 | val_acc=0.6366 | val_macro_f1=0.7236 | val_bal_acc=0.7548
# train_real | Epoch 017/100 | loss=0.0196 | train_acc=0.9908 | val_acc=0.6539 | val_macro_f1=0.7355 | val_bal_acc=0.7567
# train_real | Epoch 018/100 | loss=0.0244 | train_acc=0.9893 | val_acc=0.5950 | val_macro_f1=0.6866 | val_bal_acc=0.7219
# train_real | Epoch 019/100 | loss=0.0239 | train_acc=0.9893 | val_acc=0.6049 | val_macro_f1=0.6694 | val_bal_acc=0.7151
# train_real | Epoch 020/100 | loss=0.0235 | train_acc=0.9903 | val_acc=0.6325 | val_macro_f1=0.6940 | val_bal_acc=0.7340
# train_real | Epoch 021/100 | loss=0.0443 | train_acc=0.9817 | val_acc=0.6252 | val_macro_f1=0.7108 | val_bal_acc=0.7538
# train_real | Epoch 022/100 | loss=0.0409 | train_acc=0.9818 | val_acc=0.6556 | val_macro_f1=0.7179 | val_bal_acc=0.7409
# train_real | Epoch 023/100 | loss=0.0438 | train_acc=0.9827 | val_acc=0.5938 | val_macro_f1=0.6652 | val_bal_acc=0.7160
# train_real | Epoch 024/100 | loss=0.0231 | train_acc=0.9900 | val_acc=0.6375 | val_macro_f1=0.7189 | val_bal_acc=0.7481
# train_real | Epoch 025/100 | loss=0.0219 | train_acc=0.9921 | val_acc=0.6153 | val_macro_f1=0.6742 | val_bal_acc=0.7090
# train_real | Epoch 026/100 | loss=0.0182 | train_acc=0.9912 | val_acc=0.6304 | val_macro_f1=0.7262 | val_bal_acc=0.7606
# train_real | Epoch 027/100 | loss=0.0114 | train_acc=0.9954 | val_acc=0.6279 | val_macro_f1=0.7189 | val_bal_acc=0.7529
# train_real | Epoch 028/100 | loss=0.0148 | train_acc=0.9943 | val_acc=0.5697 | val_macro_f1=0.6344 | val_bal_acc=0.6901
# train_real | Epoch 029/100 | loss=0.0235 | train_acc=0.9891 | val_acc=0.5944 | val_macro_f1=0.6659 | val_bal_acc=0.7137
# train_real | Epoch 030/100 | loss=0.0188 | train_acc=0.9919 | val_acc=0.6055 | val_macro_f1=0.6699 | val_bal_acc=0.7162
# train_real | Epoch 031/100 | loss=0.0190 | train_acc=0.9921 | val_acc=0.6036 | val_macro_f1=0.6674 | val_bal_acc=0.7095
# train_real | Epoch 032/100 | loss=0.0192 | train_acc=0.9910 | val_acc=0.6154 | val_macro_f1=0.6972 | val_bal_acc=0.7344
# Early stopping at epoch 32. Best val macro-F1 = 0.7355
# Saved history: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/train_real_training_history.csv
# Saved model: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/train_real_best_model.pt
#
# ----------------------------------------------------------------------
# Testing trained model on: real_train_to_real_test
# ----------------------------------------------------------------------
# Test X: (10063, 512, 6)
# Test label counts: {np.int64(1): np.int64(901), np.int64(2): np.int64(635), np.int64(3): np.int64(444), np.int64(4): np.int64(697), np.int64(5): np.int64(1363), np.int64(6): np.int64(3147), np.int64(7): np.int64(1128), np.int64(8): np.int64(1748)}
# Saved: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_train_to_real_test_confusion_matrix.png
#
# ======================================================================
# Final test results | real_train_to_real_test
# ======================================================================
# accuracy                : 0.527576
# macro_precision         : 0.520254
# macro_recall            : 0.563808
# macro_f1                : 0.532448
# weighted_precision      : 0.535367
# weighted_recall         : 0.527576
# weighted_f1             : 0.524904
# balanced_accuracy       : 0.563808
#
# Per-class metrics:
#    activity  precision    recall        f1  per_class_accuracy_same_as_recall  \
# 0         1   0.659247  0.854606  0.744321                           0.854606
# 1         2   0.571613  0.697638  0.628369                           0.697638
# 2         3   0.317503  0.527027  0.396274                           0.527027
# 3         4   0.345416  0.464849  0.396330                           0.464849
# 4         5   0.602335  0.643434  0.622206                           0.643434
# 5         6   0.537190  0.475056  0.504216                           0.475056
# 6         7   0.702934  0.509752  0.590956                           0.509752
# 7         8   0.425793  0.338101  0.376913                           0.338101
#
#    support
# 0      901
# 1      635
# 2      444
# 3      697
# 4     1363
# 5     3147
# 6     1128
# 7     1748
#
# Confusion matrix:
#         pred_1  pred_2  pred_3  pred_4  pred_5  pred_6  pred_7  pred_8
# true_1     770      93       1       0       0      37       0       0
# true_2      58     443       0       0       0      14       0     120
# true_3       0      40     234       3      28      16      73      50
# true_4       5      25       2     324     166     134      41       0
# true_5       0       1     137       6     877     170       8     164
# true_6     182     123     323     156     362    1495      98     408
# true_7       9      31       0       0       3     455     575      55
# true_8     144      19      40     449      20     462      23     591
#
# Saved:
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_train_to_real_test_per_class_metrics.csv
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_train_to_real_test_confusion_matrix.csv
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_train_to_real_test_predictions.csv
#
# ----------------------------------------------------------------------
# Testing trained model on: real_train_to_synthetic_test
# ----------------------------------------------------------------------
# Test X: (46907, 512, 6)
# Test label counts: {np.int64(1): np.int64(4534), np.int64(2): np.int64(3205), np.int64(3): np.int64(2277), np.int64(4): np.int64(3439), np.int64(5): np.int64(6807), np.int64(6): np.int64(13518), np.int64(7): np.int64(4660), np.int64(8): np.int64(8467)}
# Saved: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_train_to_synthetic_test_confusion_matrix.png
#
# ======================================================================
# Final test results | real_train_to_synthetic_test
# ======================================================================
# accuracy                : 0.381329
# macro_precision         : 0.365650
# macro_recall            : 0.361264
# macro_f1                : 0.329374
# weighted_precision      : 0.375863
# weighted_recall         : 0.381329
# weighted_f1             : 0.353209
# balanced_accuracy       : 0.361264
#
# Per-class metrics:
#    activity  precision    recall        f1  per_class_accuracy_same_as_recall  \
# 0         1   0.385185  0.263785  0.313130                           0.263785
# 1         2   0.295383  0.291420  0.293388                           0.291420
# 2         3   0.224302  0.620993  0.329565                           0.620993
# 3         4   0.694665  0.382379  0.493248                           0.382379
# 4         5   0.389861  0.598795  0.472251                           0.598795
# 5         6   0.443861  0.562953  0.496364                           0.562953
# 6         7   0.205263  0.025107  0.044742                           0.025107
# 7         8   0.286684  0.144679  0.192308                           0.144679
#
#    support
# 0     4534
# 1     3205
# 2     2277
# 3     3439
# 4     6807
# 5    13518
# 6     4660
# 7     8467
#
# Confusion matrix:
#         pred_1  pred_2  pred_3  pred_4  pred_5  pred_6  pred_7  pred_8
# true_1    1196      51     345      27     577    2051      24     263
# true_2      72     934    1553     107      86     409       9      35
# true_3       9      53    1414      82     413     175      13     118
# true_4      45     173     840    1315     352     525       9     180
# true_5      15      77     199      86    4076    1196     144    1014
# true_6     906     234     666      66    2594    7610     127    1315
# true_7     201    1382    1049      64     181    1543     117     123
# true_8     661     258     238     146    2176    3636     127    1225
#
# Saved:
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_train_to_synthetic_test_per_class_metrics.csv
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_train_to_synthetic_test_confusion_matrix.csv
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_train_to_synthetic_test_predictions.csv
#
# ################################################################################
# Training: train_synthetic
# ################################################################################
# Train X: (46907, 512, 6)
# Val X:   (6740, 512, 6)
# Train label counts: {np.int64(1): np.int64(4534), np.int64(2): np.int64(3205), np.int64(3): np.int64(2277), np.int64(4): np.int64(3439), np.int64(5): np.int64(6807), np.int64(6): np.int64(13518), np.int64(7): np.int64(4660), np.int64(8): np.int64(8467)}
# Val label counts:   {np.int64(1): np.int64(629), np.int64(2): np.int64(400), np.int64(3): np.int64(331), np.int64(4): np.int64(438), np.int64(5): np.int64(943), np.int64(6): np.int64(2120), np.int64(7): np.int64(670), np.int64(8): np.int64(1209)}
#
# Class weights:
#   Activity 1: 0.9716
#   Activity 2: 1.3744
#   Activity 3: 1.9346
#   Activity 4: 1.2809
#   Activity 5: 0.6471
#   Activity 6: 0.3259
#   Activity 7: 0.9453
#   Activity 8: 0.5203
# train_synthetic | Epoch 001/100 | loss=1.1695 | train_acc=0.5323 | val_acc=0.5929 | val_macro_f1=0.6597 | val_bal_acc=0.6731
# train_synthetic | Epoch 002/100 | loss=0.7358 | train_acc=0.6706 | val_acc=0.5070 | val_macro_f1=0.5344 | val_bal_acc=0.5667
# train_synthetic | Epoch 003/100 | loss=0.4517 | train_acc=0.7699 | val_acc=0.4542 | val_macro_f1=0.4814 | val_bal_acc=0.5273
# train_synthetic | Epoch 004/100 | loss=0.2785 | train_acc=0.8551 | val_acc=0.4101 | val_macro_f1=0.4295 | val_bal_acc=0.4700
# train_synthetic | Epoch 005/100 | loss=0.1620 | train_acc=0.9162 | val_acc=0.4030 | val_macro_f1=0.4237 | val_bal_acc=0.4734
# train_synthetic | Epoch 006/100 | loss=0.1101 | train_acc=0.9427 | val_acc=0.4254 | val_macro_f1=0.4374 | val_bal_acc=0.4645
# train_synthetic | Epoch 007/100 | loss=0.0806 | train_acc=0.9590 | val_acc=0.4033 | val_macro_f1=0.3986 | val_bal_acc=0.4386
# train_synthetic | Epoch 008/100 | loss=0.0560 | train_acc=0.9716 | val_acc=0.4047 | val_macro_f1=0.3937 | val_bal_acc=0.4397
# train_synthetic | Epoch 009/100 | loss=0.0500 | train_acc=0.9740 | val_acc=0.4273 | val_macro_f1=0.3943 | val_bal_acc=0.4383
# train_synthetic | Epoch 010/100 | loss=0.0468 | train_acc=0.9778 | val_acc=0.4185 | val_macro_f1=0.4049 | val_bal_acc=0.4492
# train_synthetic | Epoch 011/100 | loss=0.0347 | train_acc=0.9828 | val_acc=0.4015 | val_macro_f1=0.3852 | val_bal_acc=0.4170
# train_synthetic | Epoch 012/100 | loss=0.0333 | train_acc=0.9842 | val_acc=0.3889 | val_macro_f1=0.3478 | val_bal_acc=0.3892
# train_synthetic | Epoch 013/100 | loss=0.0315 | train_acc=0.9851 | val_acc=0.4184 | val_macro_f1=0.3930 | val_bal_acc=0.4393
# train_synthetic | Epoch 014/100 | loss=0.0258 | train_acc=0.9870 | val_acc=0.4086 | val_macro_f1=0.3718 | val_bal_acc=0.4035
# train_synthetic | Epoch 015/100 | loss=0.0265 | train_acc=0.9872 | val_acc=0.3706 | val_macro_f1=0.3739 | val_bal_acc=0.4109
# train_synthetic | Epoch 016/100 | loss=0.0224 | train_acc=0.9893 | val_acc=0.3795 | val_macro_f1=0.3644 | val_bal_acc=0.4215
# Early stopping at epoch 16. Best val macro-F1 = 0.6597
# Saved history: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/train_synthetic_training_history.csv
# Saved model: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/train_synthetic_best_model.pt
#
# ----------------------------------------------------------------------
# Testing trained model on: synthetic_train_to_real_test
# ----------------------------------------------------------------------
# Test X: (10063, 512, 6)
# Test label counts: {np.int64(1): np.int64(901), np.int64(2): np.int64(635), np.int64(3): np.int64(444), np.int64(4): np.int64(697), np.int64(5): np.int64(1363), np.int64(6): np.int64(3147), np.int64(7): np.int64(1128), np.int64(8): np.int64(1748)}
# Saved: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/synthetic_train_to_real_test_confusion_matrix.png
#
# ======================================================================
# Final test results | synthetic_train_to_real_test
# ======================================================================
# accuracy                : 0.536222
# macro_precision         : 0.491508
# macro_recall            : 0.546502
# macro_f1                : 0.505021
# weighted_precision      : 0.569208
# weighted_recall         : 0.536222
# weighted_f1             : 0.536765
# balanced_accuracy       : 0.546502
#
# Per-class metrics:
#    activity  precision    recall        f1  per_class_accuracy_same_as_recall  \
# 0         1   0.547826  0.908990  0.683639                           0.908990
# 1         2   0.503169  0.625197  0.557584                           0.625197
# 2         3   0.201161  0.234234  0.216441                           0.234234
# 3         4   0.307560  0.513630  0.384739                           0.513630
# 4         5   0.606625  0.644901  0.625178                           0.644901
# 5         6   0.743980  0.481093  0.584330                           0.481093
# 6         7   0.553209  0.580674  0.566609                           0.580674
# 7         8   0.468531  0.383295  0.421649                           0.383295
#
#    support
# 0      901
# 1      635
# 2      444
# 3      697
# 4     1363
# 5     3147
# 6     1128
# 7     1748
#
# Confusion matrix:
#         pred_1  pred_2  pred_3  pred_4  pred_5  pred_6  pred_7  pred_8
# true_1     819       0       0       0       0       0      82       0
# true_2     189     397       0       1       0       0      44       4
# true_3      70      92     104      25     102      13      38       0
# true_4      73      81       8     358     125       0      47       5
# true_5       1      26     239      23     879      59       0     136
# true_6     111     145     164     224     325    1514     228     436
# true_7       7       8       1       0      12     266     655     179
# true_8     225      40       1     533       6     183      90     670
#
# Saved:
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/synthetic_train_to_real_test_per_class_metrics.csv
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/synthetic_train_to_real_test_confusion_matrix.csv
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/synthetic_train_to_real_test_predictions.csv
#
# ################################################################################
# Training: train_real_plus_synthetic
# ################################################################################
# Train X: (77011, 512, 6)
# Val X:   (6740, 512, 6)
# Train label counts: {np.int64(1): np.int64(7538), np.int64(2): np.int64(5375), np.int64(3): np.int64(3779), np.int64(4): np.int64(5743), np.int64(5): np.int64(11308), np.int64(6): np.int64(21769), np.int64(7): np.int64(7522), np.int64(8): np.int64(13977)}
# Val label counts:   {np.int64(1): np.int64(629), np.int64(2): np.int64(400), np.int64(3): np.int64(331), np.int64(4): np.int64(438), np.int64(5): np.int64(943), np.int64(6): np.int64(2120), np.int64(7): np.int64(670), np.int64(8): np.int64(1209)}
#
# Class weights:
#   Activity 1: 0.9681
#   Activity 2: 1.3576
#   Activity 3: 1.9310
#   Activity 4: 1.2706
#   Activity 5: 0.6453
#   Activity 6: 0.3352
#   Activity 7: 0.9701
#   Activity 8: 0.5221
# train_real_plus_synthetic | Epoch 001/100 | loss=1.0258 | train_acc=0.5848 | val_acc=0.6162 | val_macro_f1=0.6659 | val_bal_acc=0.7199
# train_real_plus_synthetic | Epoch 002/100 | loss=0.6811 | train_acc=0.6961 | val_acc=0.5481 | val_macro_f1=0.5970 | val_bal_acc=0.6597
# train_real_plus_synthetic | Epoch 003/100 | loss=0.4888 | train_acc=0.7606 | val_acc=0.5861 | val_macro_f1=0.6885 | val_bal_acc=0.7473
# train_real_plus_synthetic | Epoch 004/100 | loss=0.3618 | train_acc=0.8098 | val_acc=0.5926 | val_macro_f1=0.6595 | val_bal_acc=0.7168
# train_real_plus_synthetic | Epoch 005/100 | loss=0.2876 | train_acc=0.8474 | val_acc=0.6752 | val_macro_f1=0.7611 | val_bal_acc=0.7870
# train_real_plus_synthetic | Epoch 006/100 | loss=0.2194 | train_acc=0.8814 | val_acc=0.6736 | val_macro_f1=0.7605 | val_bal_acc=0.7879
# train_real_plus_synthetic | Epoch 007/100 | loss=0.1751 | train_acc=0.9072 | val_acc=0.6125 | val_macro_f1=0.6935 | val_bal_acc=0.7188
# train_real_plus_synthetic | Epoch 008/100 | loss=0.1322 | train_acc=0.9295 | val_acc=0.6677 | val_macro_f1=0.7499 | val_bal_acc=0.7841
# train_real_plus_synthetic | Epoch 009/100 | loss=0.1178 | train_acc=0.9384 | val_acc=0.6927 | val_macro_f1=0.7712 | val_bal_acc=0.7865
# train_real_plus_synthetic | Epoch 010/100 | loss=0.0922 | train_acc=0.9510 | val_acc=0.6975 | val_macro_f1=0.7543 | val_bal_acc=0.7670
# train_real_plus_synthetic | Epoch 011/100 | loss=0.0801 | train_acc=0.9591 | val_acc=0.6276 | val_macro_f1=0.6910 | val_bal_acc=0.7316
# train_real_plus_synthetic | Epoch 012/100 | loss=0.0728 | train_acc=0.9617 | val_acc=0.6957 | val_macro_f1=0.7624 | val_bal_acc=0.7677
# train_real_plus_synthetic | Epoch 013/100 | loss=0.0569 | train_acc=0.9705 | val_acc=0.6840 | val_macro_f1=0.7585 | val_bal_acc=0.7588
# train_real_plus_synthetic | Epoch 014/100 | loss=0.0662 | train_acc=0.9678 | val_acc=0.7033 | val_macro_f1=0.7719 | val_bal_acc=0.7654
# train_real_plus_synthetic | Epoch 015/100 | loss=0.0532 | train_acc=0.9731 | val_acc=0.6610 | val_macro_f1=0.7282 | val_bal_acc=0.7552
# train_real_plus_synthetic | Epoch 016/100 | loss=0.0443 | train_acc=0.9778 | val_acc=0.6963 | val_macro_f1=0.7714 | val_bal_acc=0.7863
# train_real_plus_synthetic | Epoch 017/100 | loss=0.0451 | train_acc=0.9769 | val_acc=0.6632 | val_macro_f1=0.7383 | val_bal_acc=0.7537
# train_real_plus_synthetic | Epoch 018/100 | loss=0.0461 | train_acc=0.9772 | val_acc=0.6380 | val_macro_f1=0.6921 | val_bal_acc=0.7183
# train_real_plus_synthetic | Epoch 019/100 | loss=0.0398 | train_acc=0.9805 | val_acc=0.7082 | val_macro_f1=0.7673 | val_bal_acc=0.7698
# train_real_plus_synthetic | Epoch 020/100 | loss=0.0380 | train_acc=0.9819 | val_acc=0.7052 | val_macro_f1=0.7684 | val_bal_acc=0.7816
# train_real_plus_synthetic | Epoch 021/100 | loss=0.0477 | train_acc=0.9778 | val_acc=0.6696 | val_macro_f1=0.7433 | val_bal_acc=0.7674
# train_real_plus_synthetic | Epoch 022/100 | loss=0.0331 | train_acc=0.9841 | val_acc=0.6553 | val_macro_f1=0.7394 | val_bal_acc=0.7652
# train_real_plus_synthetic | Epoch 023/100 | loss=0.0276 | train_acc=0.9863 | val_acc=0.6904 | val_macro_f1=0.7709 | val_bal_acc=0.7725
# train_real_plus_synthetic | Epoch 024/100 | loss=0.0366 | train_acc=0.9822 | val_acc=0.7012 | val_macro_f1=0.7632 | val_bal_acc=0.7694
# train_real_plus_synthetic | Epoch 025/100 | loss=0.0403 | train_acc=0.9816 | val_acc=0.6892 | val_macro_f1=0.7603 | val_bal_acc=0.7722
# train_real_plus_synthetic | Epoch 026/100 | loss=0.0375 | train_acc=0.9832 | val_acc=0.6869 | val_macro_f1=0.7520 | val_bal_acc=0.7684
# train_real_plus_synthetic | Epoch 027/100 | loss=0.0260 | train_acc=0.9877 | val_acc=0.6749 | val_macro_f1=0.7216 | val_bal_acc=0.7407
# train_real_plus_synthetic | Epoch 028/100 | loss=0.0313 | train_acc=0.9855 | val_acc=0.6650 | val_macro_f1=0.7203 | val_bal_acc=0.7548
# train_real_plus_synthetic | Epoch 029/100 | loss=0.0352 | train_acc=0.9838 | val_acc=0.6868 | val_macro_f1=0.7645 | val_bal_acc=0.7837
# Early stopping at epoch 29. Best val macro-F1 = 0.7719
# Saved history: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/train_real_plus_synthetic_training_history.csv
# Saved model: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/train_real_plus_synthetic_best_model.pt
#
# ----------------------------------------------------------------------
# Testing trained model on: real_plus_synthetic_train_to_real_test
# ----------------------------------------------------------------------
# Test X: (10063, 512, 6)
# Test label counts: {np.int64(1): np.int64(901), np.int64(2): np.int64(635), np.int64(3): np.int64(444), np.int64(4): np.int64(697), np.int64(5): np.int64(1363), np.int64(6): np.int64(3147), np.int64(7): np.int64(1128), np.int64(8): np.int64(1748)}
# Saved: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_plus_synthetic_train_to_real_test_confusion_matrix.png
#
# ======================================================================
# Final test results | real_plus_synthetic_train_to_real_test
# ======================================================================
# accuracy                : 0.590381
# macro_precision         : 0.627344
# macro_recall            : 0.659050
# macro_f1                : 0.618490
# weighted_precision      : 0.619661
# weighted_recall         : 0.590381
# weighted_f1             : 0.588821
# balanced_accuracy       : 0.659050
#
# Per-class metrics:
#    activity  precision    recall        f1  per_class_accuracy_same_as_recall  \
# 0         1   0.538462  0.986681  0.696708                           0.986681
# 1         2   0.773556  0.801575  0.787316                           0.801575
# 2         3   0.335366  0.743243  0.462185                           0.743243
# 3         4   0.748180  0.737446  0.742775                           0.737446
# 4         5   0.688285  0.482759  0.567486                           0.482759
# 5         6   0.561275  0.509374  0.534066                           0.509374
# 6         7   0.833333  0.531915  0.649351                           0.531915
# 7         8   0.540297  0.479405  0.508033                           0.479405
#
#    support
# 0      901
# 1      635
# 2      444
# 3      697
# 4     1363
# 5     3147
# 6     1128
# 7     1748
#
# Confusion matrix:
#         pred_1  pred_2  pred_3  pred_4  pred_5  pred_6  pred_7  pred_8
# true_1     889       0       0       0       0       4       0       8
# true_2       2     509       0       0       1      78      41       4
# true_3      39       6     330       4      15      44       5       1
# true_4       6       3      77     514      88       6       0       3
# true_5      28       5     206      10     658     334       3     119
# true_6     301      81     327       6     186    1603      65     578
# true_7       4      33       2       0       2     487     600       0
# true_8     382      21      42     153       6     300       6     838
#
# Saved:
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_plus_synthetic_train_to_real_test_per_class_metrics.csv
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_plus_synthetic_train_to_real_test_confusion_matrix.csv
#   /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/real_plus_synthetic_train_to_real_test_predictions.csv
#
# ================================================================================
# ALL CNN-BiLSTM EXPERIMENTS DONE
# ================================================================================
#                                experiment hardware channel_mode  \
# 0                 real_train_to_real_test    A6000          6ch
# 1            real_train_to_synthetic_test    A6000          6ch
# 2            synthetic_train_to_real_test    A6000          6ch
# 3  real_plus_synthetic_train_to_real_test    A6000          6ch
#
#                          channels  accuracy  macro_precision  macro_recall  \
# 0  ACC_x,ACC_y,ACC_z,BVP,EDA,TEMP  0.527576         0.520254      0.563808
# 1  ACC_x,ACC_y,ACC_z,BVP,EDA,TEMP  0.381329         0.365650      0.361264
# 2  ACC_x,ACC_y,ACC_z,BVP,EDA,TEMP  0.536222         0.491508      0.546502
# 3  ACC_x,ACC_y,ACC_z,BVP,EDA,TEMP  0.590381         0.627344      0.659050
#
#    macro_f1  weighted_precision  weighted_recall  weighted_f1  \
# 0  0.532448            0.535367         0.527576     0.524904
# 1  0.329374            0.375863         0.381329     0.353209
# 2  0.505021            0.569208         0.536222     0.536765
# 3  0.618490            0.619661         0.590381     0.588821
#
#    balanced_accuracy
# 0           0.563808
# 1           0.361264
# 2           0.546502
# 3           0.659050
#
# Saved summary: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch/summary_metrics.csv
# All outputs saved in: /home/iailab42/khans1/projects/results/cnnbilstm_timevae_downstream_6ch
